# %% [markdown]
# # This is a notebook for converting a static csv (which contains all bus routes and stops information) to an easy-to-use json file. This will be built into an stops API for displaying information relateed to stops on routes.

# %%
# import modules
import json
import pandas as pd
import numpy as np

# %%
# reaed csv as pandas dataframe
df = pd.read_csv("stops.csv")
df.reset_index()
df["RouteName"] = df["RouteName"].str.upper()
df = df. replace(np.nan, "Unknown", regex=True) 
df
# Out:
#                   ShapeId Operator  StopSequence RouteName  \
# 0      10-100-e19-1.253.O       BE             1       100
# 1      10-100-e19-1.253.O       BE             2       100
# 2      10-100-e19-1.253.O       BE             3       100
# 3      10-100-e19-1.253.O       BE             4       100
# 4      10-100-e19-1.253.O       BE             5       100
# ...                   ...      ...           ...       ...
# 78796   10-606-wbe-1.29.I     WFRD             4        W6
# 78797   10-606-wbe-1.29.I     WFRD             5        W6
# 78798   10-606-wbe-1.29.I     WFRD             6        W6
# 78799   10-606-wbe-1.29.I     WFRD             7        W6
# 78800   10-606-wbe-1.29.I     WFRD             8        W6
#
#                     RouteDescription Direction      AtcoCode PlateCode  \
# 0      Strand Street - The Long Walk         O   8240B100021  100021.0
# 1      Strand Street - The Long Walk         O  8240B1002801  100281.0
# 2      Strand Street - The Long Walk         O  8310B1326201  132621.0
# 3      Strand Street - The Long Walk         O  8300B1359501  135951.0
# 4      Strand Street - The Long Walk         O  8300B1316301  131631.0
# ...                              ...       ...           ...       ...
# 78796                      nan - nan         I   8440B352541  352541.0
# 78797                      nan - nan         I   8440B352551  352551.0
# 78798                      nan - nan         I  8440B3525801  352581.0
# 78799                      nan - nan         I  8440B3525901  352591.0
# 78800                      nan - nan         I   8440B886521   Unknown
#
#         Latitude Longitude    ShortCommonName_en   ShortCommonName_ga  \
# 0       53.58039  -6.10701         Strand Street         Sráid na Trá
# 1      53.604482 -6.184453     St Paul's Cresent         Corrán N Pól
# 2      53.674204 -6.286549          Laytown Road      Bóthar na hInse
# 3      53.711722 -6.353395  Drogheda Bus Station         Stáisiún Bus
# 4      53.825306 -6.394606               Dunleer            Dún Léire
# ...          ...       ...                   ...                  ...
# 78796  52.258168 -7.110039        Parnell Street        Sráid Parnell
# 78797  52.259724  -7.10658     Waterford Crystal  Criostail Pt Láirge
# 78798  52.261859   -7.1108        Meagher's Quay         Cé Mheachair
# 78799  52.263113  -7.11621        Merchants Quay    Cé na gCeannaithe
# 78800    Unknown   Unknown               Unknown              Unknown
#
#        HasPole  HasShelter   CarouselType   FlagData  \
# 0      No Pole  No Shelter           None       None
# 1      No Pole     Shelter           None       None
# 2      No Pole     Shelter           None       None
# 3      No Pole  No Shelter           None       None
# 4         Pole  No Shelter           None   Circular
# ...        ...         ...            ...        ...
# 78796  No Pole     Shelter  Shelter Panel   Circular
# 78797     Pole  No Shelter           None  Stretched
# 78798  No Pole     Shelter  Shelter Panel  Stretched
# 78799  No Pole  No Shelter           None   Circular
# 78800  Unknown     Unknown        Unknown    Unknown
#
#                                                RouteData
# 0                                                    100
# 1                                         100, 101, 101x
# 2                                    100, 101, 101x, 912
# 3       100, 100x, 101, 101x, 105, 163, 168, 182, 182...
# 4                                              100, 100x
# ...                                                  ...
# 78796                 360, 360a, 362, 40, w2, w3, w5, w6
# 78797                              360, 360a, w2, w5, w6
# 78798           360, 360a, 609, 610, 611, w2, w3, w5, w6
# 78799                                736, w2, w4, w5, w6
# 78800                                                 w6
#
# [78801 rows x 17 columns]

# %%
df = df.convert_dtypes()
df["StopSequence"] = df["StopSequence"].astype('string')
df["PlateCode"] = df["PlateCode"].astype('string')
df["Latitude"] = df["Latitude"].astype('string')
df["Longitude"] = df["Longitude"].astype('string')
df.dtypes
# Out:
# ShapeId               string
# Operator              string
# StopSequence          string
# RouteName             string
# RouteDescription      string
# Direction             string
# AtcoCode              string
# PlateCode             string
# Latitude              string
# Longitude             string
# ShortCommonName_en    string
# ShortCommonName_ga    string
# HasPole               string
# HasShelter            string
# CarouselType          string
# FlagData              string
# RouteData             string
# dtype: object

# %%
#drop two columns
df = df.drop(columns=["ShapeId", "CarouselType", "FlagData"])
df.count()
# Out:
# Operator              78801
# StopSequence          78801
# RouteName             78801
# RouteDescription      78801
# Direction             78801
# AtcoCode              78801
# PlateCode             78801
# Latitude              78801
# Longitude             78801
# ShortCommonName_en    78801
# ShortCommonName_ga    78801
# HasPole               78801
# HasShelter            78801
# RouteData             78801
# dtype: int64

# %%
# drop duplicated rows (same stops)
df = df.drop_duplicates(keep='first')

# %%
# group by 'RouteDescription'
df2 = df.groupby(["RouteDescription"])
df2.count()
# Out:
#                                 Operator  StopSequence  RouteName  Direction  \
# RouteDescription
# Abbey Road - Athlone Station          10            10         10         10
# Abbey Road - Cavan Bus Station        25            25         25         25
# Abbey Road - DCU                       6             6          6          6
# Abbey Road - Kells                    11            11         11         11
# Abbey Road - Kingscourt               10            10         10         10
# ...                                  ...           ...        ...        ...
# nan - St Patrick's Street              4             4          4          4
# nan - Wexford Station                 24            24         24         24
# nan - Whitegate                       13            13         13         13
# nan - Wilton Terrace                  18            18         18         18
# nan - nan                             39            39         39         39
#
#                                 AtcoCode  PlateCode  Latitude  Longitude  \
# RouteDescription
# Abbey Road - Athlone Station          10         10        10         10
# Abbey Road - Cavan Bus Station        25         25        25         25
# Abbey Road - DCU                       6          6         6          6
# Abbey Road - Kells                    11         11        11         11
# Abbey Road - Kingscourt               10         10        10         10
# ...                                  ...        ...       ...        ...
# nan - St Patrick's Street              4          4         4          4
# nan - Wexford Station                 24         24        24         24
# nan - Whitegate                       13         13        13         13
# nan - Wilton Terrace                  18         18        18         18
# nan - nan                             39         39        39         39
#
#                                 ShortCommonName_en  ShortCommonName_ga  \
# RouteDescription
# Abbey Road - Athlone Station                    10                  10
# Abbey Road - Cavan Bus Station                  25                  25
# Abbey Road - DCU                                 6                   6
# Abbey Road - Kells                              11                  11
# Abbey Road - Kingscourt                         10                  10
# ...                                            ...                 ...
# nan - St Patrick's Street                        4                   4
# nan - Wexford Station                           24                  24
# nan - Whitegate                                 13                  13
# nan - Wilton Terrace                            18                  18
# nan - nan                                       39                  39
#
#                                 HasPole  HasShelter  RouteData
# RouteDescription
# Abbey Road - Athlone Station         10          10         10
# Abbey Road - Cavan Bus Station       25          25         25
# Abbey Road - DCU                      6           6          6
# Abbey Road - Kells                   11          11         11
# Abbey Road - Kingscourt              10          10         10
# ...                                 ...         ...        ...
# nan - St Patrick's Street             4           4          4
# nan - Wexford Station                24          24         24
# nan - Whitegate                      13          13         13
# nan - Wilton Terrace                 18          18         18
# nan - nan                            39          39         39
#
# [1284 rows x 13 columns]

# %%
# store all route descriptions in a list
route_list= list(df2.groups.keys())
print(route_list[1:10])
# Out:
# ['Abbey Road - Cavan Bus Station', 'Abbey Road - DCU', 'Abbey Road - Kells', 'Abbey Road - Kingscourt', "Abbey Road - O'Connel Street", 'Abbey Road - UCD Belfield Campus', 'Abbey Road - Wilton Terrace', 'Abbey St Lower - Clontarf Castle', 'Abbey St Lower - Mourne View']

# %%
#use 46A for testing
test_group = df2.get_group("Brewery Road - Phoenix Park")
test_group.head()
# Out:
#       Operator StopSequence RouteName             RouteDescription Direction  \
# 59698       DB            1       46A  Brewery Road - Phoenix Park         I
# 59699       DB            2       46A  Brewery Road - Phoenix Park         I
# 59700       DB            3       46A  Brewery Road - Phoenix Park         I
# 59701       DB            4       46A  Brewery Road - Phoenix Park         I
# 59702       DB            5       46A  Brewery Road - Phoenix Park         I
#
#            AtcoCode PlateCode     Latitude     Longitude   ShortCommonName_en  \
# 59698  8250DB002064    2064.0  53.28272564  -6.193849161         Brewery Road
# 59699  8250DB002065    2065.0  53.28479921   -6.19485659        Merville Road
# 59700  8250DB004727    4727.0  53.29081171   -6.19778321        Laurence Park
# 59701  8250DB004728    4728.0  53.29333789  -6.201982289     Oatlands College
# 59702  8250DB000461     461.0   53.2947995  -6.203541111  Stillorgan Pk Hotel
#
#         ShortCommonName_ga  HasPole  HasShelter  \
# 59698  Bóthar na Grúdlanne  No Pole     Shelter
# 59699      Bóthar Merville  No Pole     Shelter
# 59700    Páirc San Labhrás  No Pole     Shelter
# 59701    Col Fhearann Dara  No Pole  No Shelter
# 59702  Óstán Stillorgan Pk     Pole  No Shelter
#
#                                                RouteData
# 59698                   118, 145, 155, 46a, 75, 75a, 84x
# 59699                        118, 145, 155, 46a, 75, 75a
# 59700   116, 118, 133, 133x, 145, 155, 181, 46a, 46e,...
# 59701           116, 118, 145, 155, 46a, 46e, 47, 7b, 7d
# 59702   116, 118, 145, 155, 46a, 46e, 47, 740, 740a, ...

# %%
# get route name
route_name = test_group['RouteName'].iloc[0]
print(route_name)

# get bus operator
operator = test_group['Operator'].iloc[0]
print(operator)

# get direction indicator
direction = test_group['Direction'].iloc[0]
print(direction)

# get the whole row, here first row as example
first_row = test_group.iloc[0]
print(first_row)

# get len (number of rows) of the group
print(len(test_group))
# Out:
# 46A
# DB
# I
# Operator                                             DB
# StopSequence                                          1
# RouteName                                           46A
# RouteDescription            Brewery Road - Phoenix Park
# Direction                                             I
# AtcoCode                                   8250DB002064
# PlateCode                                        2064.0
# Latitude                                    53.28272564
# Longitude                                  -6.193849161
# ShortCommonName_en                         Brewery Road
# ShortCommonName_ga                  Bóthar na Grúdlanne
# HasPole                                         No Pole
# HasShelter                                      Shelter
# RouteData              118, 145, 155, 46a, 75, 75a, 84x
# Name: 59698, dtype: string
# 41

# %%
# define a function for appending all data to a single python dictionary
def get_route_info(dataframe, RouteDescription):
    sub_group = dataframe.get_group(RouteDescription)

    operator = sub_group['Operator'].iloc[0]
    route_name = sub_group['RouteName'].iloc[0]
    direction = sub_group['Direction'].iloc[0]

    stops = {}
    for i in range(len(sub_group)):
        single_row = sub_group.iloc[i]
        stop_name_en = single_row['ShortCommonName_en']
        stop_name_ga = single_row['ShortCommonName_ga']
        stop_sequence = single_row['StopSequence']
        atco_code = single_row['AtcoCode']
        plate_code = single_row['PlateCode']
        latitude = single_row['Latitude']
        longitude = single_row['Longitude']
        has_pole = single_row['HasPole']
        has_shelter = single_row['HasShelter']
        route_data = single_row['RouteData']

        stops[stop_name_en] = {
            "stop_sequence": stop_sequence,
            "latitude": latitude,
            "longitude": longitude,
            "route_data": route_data,
            "plate_code":  plate_code, 
            "has_pole": has_pole,
            "has_shelter": has_shelter,
            "stop_name_ga": stop_name_ga,
            "atco_code": atco_code
        }

    results = {
        "operator": operator,
        "route_name": route_name,
        "direction": direction,
        "stops": stops
    }

    return results

# %%
# create an empty dict to store all data
data = {}

# iterate the route_list and append all details to the dictionary
for route in route_list:
    route_info = get_route_info(df2, route)
    data[route] = {
        "Operator": route_info['operator'],
        "RouteName": route_info['route_name'],
        "Direction": route_info['direction'],
        "stops": route_info['stops']
    }

print(data['Abbey Road - Athlone Station'])
# Out:
# {'Operator': 'BE', 'RouteName': '70', 'Direction': 'I', 'stops': {'Abbey Road': {'stop_sequence': '1', 'latitude': '53.65469707', 'longitude': '-6.684807484', 'route_data': ' 107, 109, 109a, 190', 'plate_code': '138451.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Br na Mainistreach', 'atco_code': '8310B138451'}, 'Athboy': {'stop_sequence': '2', 'latitude': '53.62189877', 'longitude': '-6.9206792', 'route_data': ' 111, 111a, 111x', 'plate_code': '135891.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Baile Átha Buí', 'atco_code': '8310B1358901'}, 'Delvin': {'stop_sequence': '3', 'latitude': '53.61180518', 'longitude': '-7.092692547', 'route_data': ' 111a, 111x', 'plate_code': '131771.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Dealbhna', 'atco_code': '8330B1317701'}, 'Castle Street': {'stop_sequence': '4', 'latitude': '53.52651374', 'longitude': '-7.340037477', 'route_data': ' 115, 115c, 22, 23, 70, 837, 842', 'plate_code': '135761.0', 'has_pole': 'Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Sráid an Chaisleáin', 'atco_code': '8330B1357601'}, 'Unknown': {'stop_sequence': '5', 'latitude': 'Unknown', 'longitude': 'Unknown', 'route_data': '70', 'plate_code': 'Unknown', 'has_pole': 'Unknown', 'has_shelter': 'Unknown', 'stop_name_ga': 'Unknown', 'atco_code': '8330B152171'}, 'Kilbeggan Square': {'stop_sequence': '6', 'latitude': '53.36810653', 'longitude': '-7.498186381', 'route_data': ' 20, 70, 763', 'plate_code': '155441.0', 'has_pole': 'Pole', 'has_shelter': 'Shelter', 'stop_name_ga': 'Crng Chill Bheagáin', 'atco_code': '8330B1554401'}, 'Horseleap': {'stop_sequence': '7', 'latitude': '53.39247683', 'longitude': '-7.581520982', 'route_data': '70', 'plate_code': '152321.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'B Átha an Urchair', 'atco_code': '8330B1523201'}, 'Moate': {'stop_sequence': '8', 'latitude': '53.39521799', 'longitude': '-7.719803662', 'route_data': ' 20, 70, 73, 763', 'plate_code': '155431.0', 'has_pole': 'Pole', 'has_shelter': 'Shelter', 'stop_name_ga': 'An Móta', 'atco_code': '8330B1554301'}, 'Athlone AIT': {'stop_sequence': '9', 'latitude': '53.41557214', 'longitude': '-7.899592102', 'route_data': ' 20, 70, 72, 73, 763, a1, a2, x20', 'plate_code': '455591.0', 'has_pole': 'Unknown', 'has_shelter': 'Unknown', 'stop_name_ga': 'ITBAL Átha Luain', 'atco_code': '8330B455591'}, 'Athlone Station': {'stop_sequence': '10', 'latitude': '53.42658765', 'longitude': '-7.935225814', 'route_data': ' 20, 440, 461, 466, 65, 70, 72, 73, x20', 'plate_code': '555101.0', 'has_pole': 'Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Stáis BÁ Luain', 'atco_code': '8330B5551001'}}}

# %%
# # finally convert the dict to json 
# json_result = json.dumps(data)
# print(json_result[:1000])

# %% [markdown]
# # Next store static data to MySQL database

# %%
from sqlalchemy import create_engine

# %%
# a method for connecting to db
def engine():
    return create_engine(
        "mysql+pymysql://{}:{}@{}:{}/{}".format(
                        "root",
                        "abcde.0358123",
                        "localhost",
                        3306,
                        "dublinbus"), echo=True)

# %%
# a method for creating the table
def create_table(engine):
    sql1 = """
    CREATE TABLE IF NOT EXISTS static_stops 
    (
        route_description VARCHAR(50),
        startpoint VARCHAR(25),
        headsign VARCHAR(25),
        operator VARCHAR(10), 
        route_name VARCHAR(10), 
        direction VARCHAR(4),
        stops JSON
    );
    """

    #execute sql
    try:
        print("creating table static_stops ...")
        engine.execute(sql1)
    except Exception as e:
        print(e)

create_table(engine())
# Out:
# creating table static_stops ...
# 2022-07-02 21:10:44,199 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-07-02 21:10:44,199 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 21:10:44,200 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-07-02 21:10:44,200 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 21:10:44,201 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-07-02 21:10:44,201 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 21:10:44,202 INFO sqlalchemy.engine.Engine
#     CREATE TABLE IF NOT EXISTS static_stops
#     (
#         route_description VARCHAR(50),
#         startpoint VARCHAR(25),
#         headsign VARCHAR(25),
#         operator VARCHAR(10),
#         route_name VARCHAR(10),
#         direction VARCHAR(4),
#         stops JSON
#     );
#
# 2022-07-02 21:10:44,202 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 21:10:44,209 INFO sqlalchemy.engine.Engine COMMIT

# %%
# get headsign dunction
def get_headsign(route_describe):
    separator = route_describe.find("-")
    headsign = route_describe[separator+2:]
    return headsign

def get_startpoint(route_describe):
    separator = route_describe.find("-")
    startpoint = route_describe[:separator-1]
    return startpoint

# %%
def insert (engine, route_list, data):
    for route in route_list:
        startpoint = get_startpoint(route)
        headsign = get_headsign(route)
        operator = data[route]['Operator']
        route_name = data[route]['RouteName']
        direction = data[route]['Direction']
        stops = json.dumps(data[route]['stops'])
        
        engine.execute(
            "INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)", (route, startpoint, headsign, operator, route_name, direction, stops)
        )

    
insert(engine=engine(), route_list=route_list, data=data)
# Out:
# 2022-07-02 21:10:44,255 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-07-02 21:10:44,255 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 21:10:44,256 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-07-02 21:10:44,256 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 21:10:44,257 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-07-02 21:10:44,258 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 21:10:44,259 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,259 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Athlone Station', 'Abbey Road', 'Athlone Station', 'BE', '70', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (2434 characters truncated) ... plate_code": "555101.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1is B\\u00c1 Luain", "atco_code": "8330B5551001"}}')
# 2022-07-02 21:10:44,263 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,264 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,265 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Cavan Bus Station', 'Abbey Road', 'Cavan Bus Station', 'BE', '109', 'O', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (6537 characters truncated) ...  "plate_code": "135861.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St Bus an Chabh\\u00e1in", "atco_code": "8520B1358601"}}')
# 2022-07-02 21:10:44,266 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,267 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,267 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - DCU', 'Abbey Road', 'DCU', 'BE', '109A', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (1296 characters truncated) ... route_data": " 109a", "plate_code": "135021.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "DCU", "atco_code": "8220B1350201"}}')
# 2022-07-02 21:10:44,268 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,268 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,269 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Kells', 'Abbey Road', 'Kells', 'BE', '107', 'O', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (2322 characters truncated) ... 9a, 109x, 187", "plate_code": "135391.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Ceanannas", "atco_code": "8310B1353901"}}')
# 2022-07-02 21:10:44,269 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,270 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,270 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Kingscourt', 'Abbey Road', 'Kingscourt', 'BE', '107', 'O', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (2051 characters truncated) ...  "plate_code": "137831.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "D\\u00fan an R\\u00ed", "atco_code": "8520B1378301"}}')
# 2022-07-02 21:10:44,272 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,274 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,275 INFO sqlalchemy.engine.Engine [raw sql] ("Abbey Road - O'Connel Street", 'Abbey Road', "O'Connel Street", 'BE', 'NX', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65443787", "longitude": "-6.684119643", "route_data": " 103x, 109x, nx", "plate_code": "138461. ... (2481 characters truncated) ... te_code": "135051.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sr\\u00e1id U\\u00ed Chonaill", "atco_code": "8220B1350501"}}')
# 2022-07-02 21:10:44,276 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,278 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,279 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - UCD Belfield Campus', 'Abbey Road', 'UCD Belfield Campus', 'BE', '103X', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65443787", "longitude": "-6.684119643", "route_data": " 103x, 109x, nx", "plate_code": "138461. ... (3951 characters truncated) ... 115, 180", "plate_code": "135061.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "COB\\u00c1C", "atco_code": "8250B1350601"}}')
# 2022-07-02 21:10:44,280 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,282 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,283 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Wilton Terrace', 'Abbey Road', 'Wilton Terrace', 'BE', 'NX', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65443787", "longitude": "-6.684119643", "route_data": " 103x, 109x, nx", "plate_code": "138461. ... (3574 characters truncated) ... nx", "plate_code": "135411.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ard\\u00e1n Wilton", "atco_code": "8220B135411"}}')
# 2022-07-02 21:10:44,285 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,287 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,287 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Clontarf Castle', 'Abbey St Lower', 'Clontarf Castle', 'DB', '130', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34889015", "longitude": "-6.256829774", "route_data": "130", "plate_code": "7591.0", "has_p ... (9676 characters truncated) ... 4, 130", "plate_code": "1767.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cais Chluain Tarbh", "atco_code": "8220DB001767"}}')
# 2022-07-02 21:10:44,289 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,290 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,291 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Mourne View', 'Abbey St Lower', 'Mourne View', 'DB', '33', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34919969", "longitude": "-6.255254959", "route_data": " 33, 33e", "plate_code": "292.0", "h ... (29558 characters truncated) ...  " 33a, 33e, 33x", "plate_code": "5176.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Reilg", "atco_code": "8240DB005176"}}')
# 2022-07-02 21:10:44,295 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,296 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,297 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Peter & Paul Church', 'Abbey St Lower', 'Peter & Paul Church', 'DB', '33', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34919969", "longitude": "-6.255254959", "route_data": " 33, 33e", "plate_code": "292.0", "h ... (27325 characters truncated) ...  33x", "plate_code": "7174.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Peadair & P\\u00f3il", "atco_code": "8240DB007174"}}')
# 2022-07-02 21:10:44,300 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,301 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,302 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Red Arches Rd', 'Abbey St Lower', 'Red Arches Rd', 'DB', '29A', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34903518", "longitude": "-6.256298123", "route_data": " 29a, 31, 31a, 31b, 32", "plate_code ... (11564 characters truncated) ... ate_code": "938.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br na n\\u00c1irs\\u00ed Dearga", "atco_code": "8240DB000938"}}')
# 2022-07-02 21:10:44,303 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,304 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,305 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Street - Colbert Station', 'Abbey Street', 'Colbert Station', 'BE', '347', 'I', '{"Abbey Street": {"stop_sequence": "1", "latitude": "52.4726851", "longitude": "-8.161024295", "route_data": " 347, 55", "plate_code": "331851.0", "h ... (1338 characters truncated) ... e_code": "635031.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "St\\u00e1isi\\u00fan Cholbaird", "atco_code": "8400B6350301"}}')
# 2022-07-02 21:10:44,306 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,307 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,307 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Street - Dromkeen', 'Abbey Street', 'Dromkeen', 'BE', '347', 'I', '{"Abbey Street": {"stop_sequence": "1", "latitude": "52.4726851", "longitude": "-8.161024295", "route_data": " 347, 55", "plate_code": "331851.0", "h ... (975 characters truncated) ... a": " 347, 55", "plate_code": "331801.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Drom Caoin", "atco_code": "8410B331801"}}')
# 2022-07-02 21:10:44,308 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,309 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,310 INFO sqlalchemy.engine.Engine [raw sql] ('Abbeyfeale - Casement Station', 'Abbeyfeale', 'Casement Station', 'BE', '13', 'O', '{"Abbeyfeale": {"stop_sequence": "1", "latitude": "52.38654882", "longitude": "-9.295100275", "route_data": " 13, 14, 271, 300", "plate_code": "63566 ... (2731 characters truncated) ... "plate_code": "600091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "IT Thr\\u00e1 L\\u00ed", "atco_code": "8390B6000901"}}')
# 2022-07-02 21:10:44,311 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,312 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,312 INFO sqlalchemy.engine.Engine [raw sql] ('Abbeyfeale - Killarney Bus Stn', 'Abbeyfeale', 'Killarney Bus Stn', 'BE', '14', 'O', '{"Abbeyfeale": {"stop_sequence": "1", "latitude": "52.38654882", "longitude": "-9.295100275", "route_data": " 13, 14, 271, 300", "plate_code": "63566 ... (1643 characters truncated) ... , "plate_code": "635601.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "St\\u00e1is Chill Airne", "atco_code": "8390B6356001"}}')
# 2022-07-02 21:10:44,313 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,315 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,315 INFO sqlalchemy.engine.Engine [raw sql] ('Adamstown Station - Merrion Sq South', 'Adamstown Station', 'Merrion Sq South', 'DB', '25B', 'I', '{"Adamstown Station": {"stop_sequence": "1", "latitude": "53.33620092", "longitude": "-6.468505098", "route_data": " 25b", "plate_code": "6290.0", "h ... (11645 characters truncated) ... 6x, 67x", "plate_code": "7049.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "P\\u00e1irc Vesey", "atco_code": "8230DB007049"}}')
# 2022-07-02 21:10:44,317 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,318 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,319 INFO sqlalchemy.engine.Engine [raw sql] ('Aisling Place - Commons Road', 'Aisling Place', 'Commons Road', 'BE', 'N2', 'I', '{"Aisling Place": {"stop_sequence": "1", "latitude": "53.66381724", "longitude": "-6.676488506", "route_data": " n2", "plate_code": "189311.0", "has_ ... (4688 characters truncated) ... ate_code": "189001.0", "has_pole": "Unknown", "has_shelter": "Unknown", "stop_name_ga": "B\\u00f3thar an Choim\\u00edn", "atco_code": "8310B189001"}}')
# 2022-07-02 21:10:44,320 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,321 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,321 INFO sqlalchemy.engine.Engine [raw sql] ('Alverno Terrace - Drogheda Bus Station', 'Alverno Terrace', 'Drogheda Bus Station', 'BE', 'D1', 'I', '{"Alverno Terrace": {"stop_sequence": "1", "latitude": "53.67856622", "longitude": "-6.240261146", "route_data": " 910, d1, d2", "plate_code": "10933 ... (4346 characters truncated) ... "111791.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Pl\\u00e1s\\u00f3ga Na M\\u00ednleach", "atco_code": "8310B111791"}}')
# 2022-07-02 21:10:44,322 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,323 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,324 INFO sqlalchemy.engine.Engine [raw sql] ('Annagassan - Drogheda Bus Station', 'Annagassan', 'Drogheda Bus Station', 'BE', '168', 'O', '{"Annagassan": {"stop_sequence": "1", "latitude": "53.88236537", "longitude": "-6.342998952", "route_data": "168", "plate_code": "107041.0", "has_pol ... (2987 characters truncated) ... late_code": "135951.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1isi\\u00fan Bus", "atco_code": "8300B1359501"}}')
# 2022-07-02 21:10:44,325 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,327 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,327 INFO sqlalchemy.engine.Engine [raw sql] ('Annagassan - The Long Walk', 'Annagassan', 'The Long Walk', 'BE', '168', 'I', '{"Annagassan": {"stop_sequence": "1", "latitude": "53.88220075", "longitude": "-6.342792505", "route_data": "168", "plate_code": "109661.0", "has_pol ... (3060 characters truncated) ... te_code": "105091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Si\\u00fal\\u00e1n Fada", "atco_code": "8300B1050901"}}')
# 2022-07-02 21:10:44,330 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,333 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,333 INFO sqlalchemy.engine.Engine [raw sql] ('Apple Inc - Mahon Point SC', 'Apple Inc', 'Mahon Point SC', 'BE', '202', 'I', '{"Apple Inc": {"stop_sequence": "1", "latitude": "51.9053791", "longitude": "-8.51533124", "route_data": " 201, 202, 202a", "plate_code": "298951.0", ... (11683 characters truncated) ... 212, 219", "plate_code": "246851.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br Rinn Mhachan", "atco_code": "8370B246851"}}')
# 2022-07-02 21:10:44,337 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,339 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,339 INFO sqlalchemy.engine.Engine [raw sql] ('Apple Inc - Merchants Quay', 'Apple Inc', 'Merchants Quay', 'BE', '202', 'I', '{"Apple Inc": {"stop_sequence": "1", "latitude": "51.9053791", "longitude": "-8.51533124", "route_data": " 201, 202, 202a", "plate_code": "298951.0", ... (4591 characters truncated) ... ", "plate_code": "299021.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "C\\u00e9 na gCeannaithe", "atco_code": "8370B299021"}}')
# 2022-07-02 21:10:44,340 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,342 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,342 INFO sqlalchemy.engine.Engine [raw sql] ('Ardee Bypass - Drogheda Bus Station', 'Ardee Bypass', 'Drogheda Bus Station', 'BE', '182A', 'I', '{"Ardee Bypass": {"stop_sequence": "1", "latitude": "53.86472765", "longitude": "-6.541312241", "route_data": " 180, 182, 182a, 32", "plate_code": "1 ... (1923 characters truncated) ... late_code": "135951.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1isi\\u00fan Bus", "atco_code": "8300B1359501"}}')
# 2022-07-02 21:10:44,343 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,345 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,345 INFO sqlalchemy.engine.Engine [raw sql] ('Ardee Lidl - The Long Walk', 'Ardee Lidl', 'The Long Walk', 'BE', '167', 'I', '{"Ardee Lidl": {"stop_sequence": "1", "latitude": "53.84548081", "longitude": "-6.538638058", "route_data": " 167, 182, 182a", "plate_code": "109461. ... (2411 characters truncated) ... te_code": "105091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Si\\u00fal\\u00e1n Fada", "atco_code": "8300B1050901"}}')
# 2022-07-02 21:10:44,347 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,349 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,349 INFO sqlalchemy.engine.Engine [raw sql] ('Ardmore - Parnell Place', 'Ardmore', 'Parnell Place', 'BE', '260', 'I', '{"Ardmore": {"stop_sequence": "1", "latitude": "51.95089685", "longitude": "-7.724573629", "route_data": "260", "plate_code": "244601.0", "has_pole": ... (9227 characters truncated) ... "260", "plate_code": "232771.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br Dhr na Scuab", "atco_code": "8380B2327701"}}')
# 2022-07-02 21:10:44,352 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,354 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,354 INFO sqlalchemy.engine.Engine [raw sql] ('Ardmore - Youghal', 'Ardmore', 'Youghal', 'BE', '260', 'I', '{"Ardmore": {"stop_sequence": "1", "latitude": "51.95089685", "longitude": "-7.724573629", "route_data": "260", "plate_code": "244601.0", "has_pole": ... (1270 characters truncated) ... ta": " 260, 40", "plate_code": "216341.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Eochaill", "atco_code": "8380B2163401"}}')
# 2022-07-02 21:10:44,356 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,357 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,357 INFO sqlalchemy.engine.Engine [raw sql] ('Ardnacrusha - Arthurs Quay', 'Ardnacrusha', 'Arthurs Quay', 'BE', '313', 'I', '{"Ardnacrusha": {"stop_sequence": "1", "latitude": "52.70694665", "longitude": "-8.618718342", "route_data": "313", "plate_code": "332061.0", "has_po ... (1555 characters truncated) ... 5", "plate_code": "605551.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "C\\u00e9 Art\\u00fair", "atco_code": "8400B6055501"}}')
# 2022-07-02 21:10:44,358 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,359 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,360 INFO sqlalchemy.engine.Engine [raw sql] ('Ardnacrusha - Colbert Station', 'Ardnacrusha', 'Colbert Station', 'BE', '313', 'I', '{"Ardnacrusha": {"stop_sequence": "1", "latitude": "52.70694665", "longitude": "-8.618718342", "route_data": "313", "plate_code": "332061.0", "has_po ... (3237 characters truncated) ... 313", "plate_code": "606741.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Bruach na Sionainne", "atco_code": "8360B6067401"}}')
# 2022-07-02 21:10:44,361 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,362 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,363 INFO sqlalchemy.engine.Engine [raw sql] ('Arklow - Custom House Quay', 'Arklow', 'Custom House Quay', 'BE', '133', 'I', '{"Arklow": {"stop_sequence": "1", "latitude": "52.79835209", "longitude": "-6.156799695", "route_data": " 133, 133l, 133x, 2", "plate_code": "135531. ... (4409 characters truncated) ... late_code": "101971.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "C\\u00e9 Thch an Chustaim", "atco_code": "8220B101971"}}')
# 2022-07-02 21:10:44,364 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,365 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,366 INFO sqlalchemy.engine.Engine [raw sql] ('Arthurs Quay - Ardnacrusha', 'Arthurs Quay', 'Ardnacrusha', 'BE', '313', 'O', '{"Arthurs Quay": {"stop_sequence": "1", "latitude": "52.66530072", "longitude": "-8.626364536", "route_data": " 313, 315", "plate_code": "605551.0",  ... (3156 characters truncated) ... , "plate_code": "333781.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cnoc na Ghi\\u00faise", "atco_code": "8360B333781"}}')
# 2022-07-02 21:10:44,367 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,368 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,368 INFO sqlalchemy.engine.Engine [raw sql] ('Arthurs Quay - St Nicholas Church', 'Arthurs Quay', 'St Nicholas Church', 'BE', '301', 'O', '{"Arthurs Quay": {"stop_sequence": "1", "latitude": "52.66511135", "longitude": "-8.626480098", "route_data": " 301, 323, 323x, 341, 345", "plate_cod ... (4011 characters truncated) ... e": "606721.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "S\\u00e9ip\\u00e9al San Nicholas", "atco_code": "8360B6067201"}}')
# 2022-07-02 21:10:44,369 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,370 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,371 INFO sqlalchemy.engine.Engine [raw sql] ('Ash Lane - Busáras', 'Ash Lane', 'Busáras', 'BE', '23', 'I', '{"Ash Lane": {"stop_sequence": "1", "latitude": "54.27620448", "longitude": "-8.460225326", "route_data": " 23, 462, 475", "plate_code": "524861.0",  ... (6179 characters truncated) ... 30, x4", "plate_code": "111911.0", "has_pole": "Unknown", "has_shelter": "Unknown", "stop_name_ga": "Aerfort B\\u00c1C", "atco_code": "8240B111911"}}')
# 2022-07-02 21:10:44,372 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,373 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,374 INFO sqlalchemy.engine.Engine [raw sql] ('Ash Lane - Coolaney', 'Ash Lane', 'Coolaney', 'BE', '475', 'O', '{"Ash Lane": {"stop_sequence": "1", "latitude": "54.27620448", "longitude": "-8.460225326", "route_data": " 23, 462, 475", "plate_code": "524861.0",  ... (2442 characters truncated) ... 5", "plate_code": "556441.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "C\\u00fail \\u00c1ine", "atco_code": "8510B5564401"}}')
# 2022-07-02 21:10:44,376 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,377 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,377 INFO sqlalchemy.engine.Engine [raw sql] ('Ashington Park - Drimnagh PO', 'Ashington Park', 'Drimnagh PO', 'DB', '122', 'O', '{"Ashington Park": {"stop_sequence": "1", "latitude": "53.37344814", "longitude": "-6.311390924", "route_data": "122", "plate_code": "4525.0", "has_p ... (13745 characters truncated) ... 122, 123", "plate_code": "6094.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "OP Dhroimeanaigh", "atco_code": "8220DB006094"}}')
# 2022-07-02 21:10:44,379 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,381 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,381 INFO sqlalchemy.engine.Engine [raw sql] ('Ashington Park - Parnell Square East', 'Ashington Park', 'Parnell Square East', 'DB', '122', 'O', '{"Ashington Park": {"stop_sequence": "1", "latitude": "53.37344814", "longitude": "-6.311390924", "route_data": "122", "plate_code": "4525.0", "has_p ... (5626 characters truncated) ... 0, 122, 9", "plate_code": "263.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cg Parnell Thoir", "atco_code": "8220DB000263"}}')
# 2022-07-02 21:10:44,382 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,384 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,384 INFO sqlalchemy.engine.Engine [raw sql] ('Ashleigh Green - Wilton Terrace', 'Ashleigh Green', 'Wilton Terrace', 'DB', '37', 'I', '{"Ashleigh Green": {"stop_sequence": "1", "latitude": "53.37958851", "longitude": "-6.367711534", "route_data": " 37, 38", "plate_code": "1687.0", "h ... (10884 characters truncated) ... "37", "plate_code": "7340.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ard\\u00e1n Wilton", "atco_code": "8220DB007340"}}')
# 2022-07-02 21:10:44,386 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,387 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,387 INFO sqlalchemy.engine.Engine [raw sql] ('Ashmount Terminus - Curraheen Village', 'Ashmount Terminus', 'Curraheen Village', 'BE', '208', 'O', '{"Ashmount Terminus": {"stop_sequence": "1", "latitude": "51.90815184", "longitude": "-8.419207938", "route_data": "208", "plate_code": "246491.0", " ... (11119 characters truncated) ... 08", "plate_code": "210211.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Churraich\\u00edn", "atco_code": "8380B2102101"}}')
# 2022-07-02 21:10:44,389 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,390 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,390 INFO sqlalchemy.engine.Engine [raw sql] ('Ashmount Terminus - Marymount Hospice', 'Ashmount Terminus', 'Marymount Hospice', 'BE', '208', 'O', '{"Ashmount Terminus": {"stop_sequence": "1", "latitude": "51.90815184", "longitude": "-8.419207938", "route_data": "208", "plate_code": "246491.0", " ... (10303 characters truncated) ... 40", "plate_code": "237221.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Osp\\u00eds Marymount", "atco_code": "8380B237221"}}')
# 2022-07-02 21:10:44,392 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,393 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,394 INFO sqlalchemy.engine.Engine [raw sql] ("Ashmount Terminus - St Patrick's Street", 'Ashmount Terminus', "St Patrick's Street", 'BE', '208', 'O', '{"Ashmount Terminus": {"stop_sequence": "1", "latitude": "51.90815184", "longitude": "-8.419207938", "route_data": "208", "plate_code": "246491.0", " ... (4400 characters truncated) ... e_code": "240491.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Sr\\u00e1id Naomh P\\u00e1draig", "atco_code": "8370B240491"}}')
# 2022-07-02 21:10:44,395 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,398 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,398 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Quay - Park West Hotel', 'Aston Quay', 'Park West Hotel', 'DB', '79A', 'O', '{"Aston Quay": {"stop_sequence": "1", "latitude": "53.34655354", "longitude": "-6.260544947", "route_data": " 79, 79a", "plate_code": "326.0", "has_p ... (9146 characters truncated) ... "plate_code": "6029.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "\\u00d3st\\u00e1n Park West", "atco_code": "8220DB006029"}}')
# 2022-07-02 21:10:44,400 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,402 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,403 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Quay - Spiddal Park', 'Aston Quay', 'Spiddal Park', 'DB', '79', 'O', '{"Aston Quay": {"stop_sequence": "1", "latitude": "53.34655354", "longitude": "-6.260544947", "route_data": " 79, 79a", "plate_code": "326.0", "has_p ... (8804 characters truncated) ... plate_code": "2908.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "P\\u00e1irc an Spid\\u00e9il", "atco_code": "8220DB002908"}}')
# 2022-07-02 21:10:44,405 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,407 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,408 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Quay - Woodford Hill', 'Aston Quay', 'Woodford Hill', 'DB', '51D', 'O', '{"Aston Quay": {"stop_sequence": "1", "latitude": "53.34646042", "longitude": "-6.260939259", "route_data": " 25, 25a, 25b, 51d, 860", "plate_code":  ... (11755 characters truncated) ... ", "plate_code": "1966.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Cnoc \\u00c1th na Coille", "atco_code": "8230DB001966"}}')
# 2022-07-02 21:10:44,410 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,412 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,412 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Village - Deepforde Estate', 'Aston Village', 'Deepforde Estate', 'BE', 'D5', 'I', '{"Aston Village": {"stop_sequence": "1", "latitude": "53.73288424", "longitude": "-6.32981665", "route_data": " 101x, 173, d5", "plate_code": "136021 ... (2234 characters truncated) ... ", "plate_code": "100631.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "East\\u00e1t Deepforde", "atco_code": "8310B1006301"}}')
# 2022-07-02 21:10:44,413 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,415 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,415 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Village - Wilton Terrace', 'Aston Village', 'Wilton Terrace', 'BE', '101X', 'I', '{"Aston Village": {"stop_sequence": "1", "latitude": "53.73288424", "longitude": "-6.32981665", "route_data": " 101x, 173, d5", "plate_code": "136021 ... (8427 characters truncated) ... , nx", "plate_code": "135311.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ard\\u00e1n Wilton", "atco_code": "8220B1353101"}}')
# 2022-07-02 21:10:44,420 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,429 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,432 INFO sqlalchemy.engine.Engine [raw sql] ('Athboy - Busáras', 'Athboy', 'Busáras', 'BE', '111', 'I', '{"Athboy": {"stop_sequence": "1", "latitude": "53.62173991", "longitude": "-6.921000697", "route_data": " 111, 111a, 111x", "plate_code": "103021.0", ... (6209 characters truncated) ... 11", "plate_code": "103131.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Eaglais Chill Dealga", "atco_code": "8310B1031301"}}')
# 2022-07-02 21:10:44,438 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,450 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,452 INFO sqlalchemy.engine.Engine [raw sql] ('Athboy - Cavan Bus Station', 'Athboy', 'Cavan Bus Station', 'BE', '111A', 'I', '{"Athboy": {"stop_sequence": "1", "latitude": "53.62189877", "longitude": "-6.9206792", "route_data": " 111, 111a, 111x", "plate_code": "135891.0", " ... (2134 characters truncated) ...  "plate_code": "135861.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St Bus an Chabh\\u00e1in", "atco_code": "8520B1358601"}}')
# 2022-07-02 21:10:44,455 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,458 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,458 INFO sqlalchemy.engine.Engine [raw sql] ('Athboy - UCD Belfield Campus', 'Athboy', 'UCD Belfield Campus', 'BE', '111', 'I', '{"Athboy": {"stop_sequence": "1", "latitude": "53.62173991", "longitude": "-6.921000697", "route_data": " 111, 111a, 111x", "plate_code": "103021.0", ... (6189 characters truncated) ... 115, 180", "plate_code": "135061.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "COB\\u00c1C", "atco_code": "8250B1350601"}}')
# 2022-07-02 21:10:44,460 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,462 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,462 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Abbey Road', 'Athlone Station', 'Abbey Road', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (2469 characters truncated) ... 90", "plate_code": "138451.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br na Mainistreach", "atco_code": "8310B138451"}}')
# 2022-07-02 21:10:44,463 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,464 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,465 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Castle Street', 'Athlone Station', 'Castle Street', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1671 characters truncated) ... _code": "135761.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sr\\u00e1id an Chaisle\\u00e1in", "atco_code": "8330B1357601"}}')
# 2022-07-02 21:10:44,466 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,468 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,468 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Claremorris', 'Athlone Station', 'Claremorris', 'BE', '440', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (3209 characters truncated) ... , 64", "plate_code": "151051.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cl Chlainne Mhuiris", "atco_code": "8490B151051"}}')
# 2022-07-02 21:10:44,470 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,471 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,472 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Colbert Station', 'Athlone Station', 'Colbert Station', 'BE', '72', 'I', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (4171 characters truncated) ...  a2", "plate_code": "500191.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Oile\\u00e1n Golden", "atco_code": "8330B5001901"}}')
# 2022-07-02 21:10:44,475 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,477 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,479 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Longford Station', 'Athlone Station', 'Longford Station', 'BE', '466', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1347 characters truncated) ...  a2", "plate_code": "500191.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Oile\\u00e1n Golden", "atco_code": "8330B5001901"}}')
# 2022-07-02 21:10:44,481 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,484 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,485 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Mart Road', 'Athlone Station', 'Mart Road', 'BE', '461', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1356 characters truncated) ... te_code": "555751.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "B\\u00f3thar na Marglainne", "atco_code": "8500B5557501"}}')
# 2022-07-02 21:10:44,493 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,502 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,503 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Mill Street', 'Athlone Station', 'Mill Street', 'BE', '440', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (7538 characters truncated) ... , "plate_code": "555711.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sr\\u00e1id an Mhuilinn", "atco_code": "8490B5557101"}}')
# 2022-07-02 21:10:44,505 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,506 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,507 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Monaghan Bus Stn', 'Athlone Station', 'Monaghan Bus Stn', 'BE', '65', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (2496 characters truncated) ... te_code": "155921.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Stn Bus Mhuineach\\u00e1in", "atco_code": "8540B1559201"}}')
# 2022-07-02 21:10:44,509 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,510 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,511 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Mullingar Station', 'Athlone Station', 'Mullingar Station', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1884 characters truncated) ... 0", "plate_code": "555391.0", "has_pole": "Unknown", "has_shelter": "Unknown", "stop_name_ga": "ITBAL \\u00c1tha Luain", "atco_code": "8330B555391"}}')
# 2022-07-02 21:10:44,512 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,513 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,514 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - The Long Walk', 'Athlone Station', 'The Long Walk', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (3979 characters truncated) ... te_code": "105091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Si\\u00fal\\u00e1n Fada", "atco_code": "8300B1050901"}}')
# 2022-07-02 21:10:44,515 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,516 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,517 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Waterford Bus Stn', 'Athlone Station', 'Waterford Bus Stn', 'BE', '73', 'I', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (4935 characters truncated) ... late_code": "355051.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1is Phort Lairge", "atco_code": "8440B3550501"}}')
# 2022-07-02 21:10:44,518 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,519 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,520 INFO sqlalchemy.engine.Engine [raw sql] ('Aulden Grange - Eden Quay', 'Aulden Grange', 'Eden Quay', 'DB', '27B', 'I', '{"Aulden Grange": {"stop_sequence": "1", "latitude": "53.39740937", "longitude": "-6.232485568", "route_data": " 17a, 27b", "plate_code": "7044.0", " ... (10312 characters truncated) ...  61, 84x", "plate_code": "303.0", "has_pole": "Pole", "has_shelter": "Shelter", "stop_name_ga": "C\\u00e9 \\u00c9idin", "atco_code": "8220DB000303"}}')
# 2022-07-02 21:10:44,522 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,523 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,524 INFO sqlalchemy.engine.Engine [raw sql] ('Bailieborough - Kells', 'Bailieborough', 'Kells', 'BE', '108', 'I', '{"Bailieborough": {"stop_sequence": "1", "latitude": "53.91622076", "longitude": "-6.969365197", "route_data": " 108, 166", "plate_code": "130911.0", ... (986 characters truncated) ... 9a, 109x, 187", "plate_code": "135391.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Ceanannas", "atco_code": "8310B1353901"}}')
# 2022-07-02 21:10:44,525 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,526 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,527 INFO sqlalchemy.engine.Engine [raw sql] ('Balbriggan Station - Millfield Centre', 'Balbriggan Station', 'Millfield Centre', 'BE', 'B1', 'O', '{"Balbriggan Station": {"stop_sequence": "1", "latitude": "53.61166546", "longitude": "-6.182799777", "route_data": " b1", "plate_code": "134741.0",  ... (1883 characters truncated) ... a": " 191, b1", "plate_code": "134861.0", "has_pole": "Pole", "has_shelter": "Shelter", "stop_name_ga": "IS Millfield", "atco_code": "8240B1348601"}}')
# 2022-07-02 21:10:44,528 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,529 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:44,530 INFO sqlalchemy.engine.Engine [raw sql] ('Balbriggan Station - The Hastings', 'Balbriggan Station', 'The Hastings', 'BE', 'B1', 'O', '{"Balbriggan Station": {"stop_sequence": "1", "latitude": "53.61166546", "longitude": "-6.182799777", "route_data": " b1", "plate_code": "134741.0",  ... (1339 characters truncated) ... ata": " b1", "plate_code": "134771.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "The Hastings", "atco_code": "8240B1347701"}}')
# 2022-07-02 21:10:44,531 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:44,532 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# ...
# 2022-07-02 21:10:47,888 INFO sqlalchemy.engine.Engine [raw sql] ('Talbot Street - Sutton Castle', 'Talbot Street', 'Sutton Castle', 'DB', '31A', 'O', '{"Talbot Street": {"stop_sequence": "1", "latitude": "53.35051778", "longitude": "-6.256267648", "route_data": " 130, 29a, 31, 31a, 31b, 32", "plate_ ... (19733 characters truncated) ... 31a, 31b", "plate_code": "686.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cais C Fhionntain", "atco_code": "8240DB000686"}}')
# 2022-07-02 21:10:47,890 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,890 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,891 INFO sqlalchemy.engine.Engine [raw sql] ('Talbot Street - Sutton Cross', 'Talbot Street', 'Sutton Cross', 'DB', '31', 'O', '{"Talbot Street": {"stop_sequence": "1", "latitude": "53.35051778", "longitude": "-6.256267648", "route_data": " 130, 29a, 31, 31a, 31b, 32", "plate_ ... (18402 characters truncated) ... late_code": "693.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "S\\u00e9ip\\u00e9al Fhionntain", "atco_code": "8240DB000693"}}')
# 2022-07-02 21:10:47,892 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,893 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,893 INFO sqlalchemy.engine.Engine [raw sql] ('Tayto Park - Connolly Hospital', 'Tayto Park', 'Connolly Hospital', 'BE', '105', 'I', '{"Tayto Park": {"stop_sequence": "1", "latitude": "53.54580811", "longitude": "-6.458382019", "route_data": " 103, 105", "plate_code": "137241.0", "h ... (6435 characters truncated) ... a", "plate_code": "7297.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Osp U\\u00ed Chonghaile", "atco_code": "8240DB007297"}}')
# 2022-07-02 21:10:47,894 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,895 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,896 INFO sqlalchemy.engine.Engine [raw sql] ('Tayto Park - Gardiner St Lower', 'Tayto Park', 'Gardiner St Lower', 'BE', '103', 'I', '{"Tayto Park": {"stop_sequence": "1", "latitude": "53.54580811", "longitude": "-6.458382019", "route_data": " 103, 105", "plate_code": "137241.0", "h ... (6975 characters truncated) ... te_code": "135031.0", "has_pole": "Pole", "has_shelter": "Shelter", "stop_name_ga": "Sd Ghairdin\\u00e9ir \\u00cdocht", "atco_code": "8220B1350301"}}')
# 2022-07-02 21:10:47,897 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,898 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,898 INFO sqlalchemy.engine.Engine [raw sql] ('Temple Road - Bray Station', 'Temple Road', 'Bray Station', 'DB', '84A', 'O', '{"Temple Road": {"stop_sequence": "1", "latitude": "53.29947658", "longitude": "-6.174747752", "route_data": " 84, 84a", "plate_code": "7188.0", "has ... (10814 characters truncated) ... te_code": "4168.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1isi\\u00fan Bhr\\u00e9", "atco_code": "8350DB004168"}}')
# 2022-07-02 21:10:47,899 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,900 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,900 INFO sqlalchemy.engine.Engine [raw sql] ('Temple Road - Sea Road', 'Temple Road', 'Sea Road', 'DB', '84', 'O', '{"Temple Road": {"stop_sequence": "1", "latitude": "53.29947658", "longitude": "-6.174747752", "route_data": " 84, 84a", "plate_code": "7188.0", "has ... (23163 characters truncated) ... plate_code": "4306.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Gleannt\\u00e1n na Fe\\u00e1", "atco_code": "8350DB004306"}}')
# 2022-07-02 21:10:47,902 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,902 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,903 INFO sqlalchemy.engine.Engine [raw sql] ('Templeshannon - The Quay', 'Templeshannon', 'The Quay', 'BE', '375', 'I', '{"Templeshannon": {"stop_sequence": "1", "latitude": "52.50148542", "longitude": "-6.564318481", "route_data": " 2, 376, 740, x2", "plate_code": "355 ... (256 characters truncated) ... 40, 882, x4", "plate_code": "355461.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "An Ch\\u00e9", "atco_code": "8340B355461"}}')
# 2022-07-02 21:10:47,903 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,904 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,904 INFO sqlalchemy.engine.Engine [raw sql] ('Templeshannon - Wexford Station', 'Templeshannon', 'Wexford Station', 'BE', '377', 'I', '{"Templeshannon": {"stop_sequence": "1", "latitude": "52.50148542", "longitude": "-6.564318481", "route_data": " 2, 376, 740, x2", "plate_code": "355 ... (543 characters truncated) ...  40, x2", "plate_code": "355511.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Stn Loch Garman", "atco_code": "8340B3555101"}}')
# 2022-07-02 21:10:47,905 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,905 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,905 INFO sqlalchemy.engine.Engine [raw sql] ('Templeview Avenue - Eden Quay', 'Templeview Avenue', 'Eden Quay', 'DB', '27', 'O', '{"Templeview Avenue": {"stop_sequence": "1", "latitude": "53.40213992", "longitude": "-6.172972588", "route_data": " 15, 27, 27x", "plate_code": "459 ... (10877 characters truncated) ...  33x, 61", "plate_code": "302.0", "has_pole": "Pole", "has_shelter": "Shelter", "stop_name_ga": "C\\u00e9 \\u00c9idin", "atco_code": "8220DB000302"}}')
# 2022-07-02 21:10:47,907 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,908 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,908 INFO sqlalchemy.engine.Engine [raw sql] ('Templeview Avenue - Fortunestown Road', 'Templeview Avenue', 'Fortunestown Road', 'DB', '27', 'O', '{"Templeview Avenue": {"stop_sequence": "1", "latitude": "53.40213992", "longitude": "-6.172972588", "route_data": " 15, 27, 27x", "plate_code": "459 ... (24793 characters truncated) ... late_code": "2355.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br B U\\u00ed Fhoirtcheirn", "atco_code": "8230DB002355"}}')
# 2022-07-02 21:10:47,909 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,911 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,911 INFO sqlalchemy.engine.Engine [raw sql] ('Templeview Avenue - UCD', 'Templeview Avenue', 'UCD', 'DB', '27X', 'I', '{"Templeview Avenue": {"stop_sequence": "1", "latitude": "53.40213992", "longitude": "-6.172972588", "route_data": " 15, 27, 27x", "plate_code": "459 ... (12381 characters truncated) ...  702, 703", "plate_code": "416.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "RDS Dr na Dothra", "atco_code": "8220DB000416"}}')
# 2022-07-02 21:10:47,912 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,913 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,913 INFO sqlalchemy.engine.Engine [raw sql] ("The Clock Tower - Meagher's Quay", 'The Clock Tower', "Meagher's Quay", 'WFRD', 'W3', 'O', '{"The Clock Tower": {"stop_sequence": "1", "latitude": "52.26209234", "longitude": "-7.110751219", "route_data": " 340, 360, 360a, 609, 611, w1, w2,  ... (9788 characters truncated) ...  "plate_code": "352551.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Criostail Pt L\\u00e1irge", "atco_code": "8440B352551"}}')
# 2022-07-02 21:10:47,914 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,915 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,916 INFO sqlalchemy.engine.Engine [raw sql] ('The Clock Tower - Merchants Quay', 'The Clock Tower', 'Merchants Quay', 'WFRD', 'W1', 'O', '{"The Clock Tower": {"stop_sequence": "1", "latitude": "52.26209234", "longitude": "-7.110751219", "route_data": " 340, 360, 360a, 609, 611, w1, w2,  ... (6062 characters truncated) ... "plate_code": "352561.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "C\\u00e9 na gCeannaithe", "atco_code": "8440B352561"}}')
# 2022-07-02 21:10:47,917 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,917 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,918 INFO sqlalchemy.engine.Engine [raw sql] ('The Hastings - Balbriggan Station', 'The Hastings', 'Balbriggan Station', 'BE', 'B1', 'I', '{"The Hastings": {"stop_sequence": "1", "latitude": "53.61334557", "longitude": "-6.209586609", "route_data": " b1", "plate_code": "134771.0", "has_p ... (1567 characters truncated) ... de": "134741.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1is Bhaile Brig\\u00edn", "atco_code": "8240B1347401"}}')
# 2022-07-02 21:10:47,918 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,919 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,919 INFO sqlalchemy.engine.Engine [raw sql] ('The Long Walk - Ardee Lidl', 'The Long Walk', 'Ardee Lidl', 'BE', '167', 'O', '{"The Long Walk": {"stop_sequence": "1", "latitude": "54.00573544", "longitude": "-6.404328583", "route_data": " 100, 100x, 160, 161, 162, 166, 167,  ... (2133 characters truncated) ... a", "plate_code": "109461.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Lidl B\\u00c1 Fhirdhia", "atco_code": "8300B109461"}}')
# 2022-07-02 21:10:47,920 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,921 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,921 INFO sqlalchemy.engine.Engine [raw sql] ('The Long Walk - Athlone Station', 'The Long Walk', 'Athlone Station', 'BE', '70', 'I', '{"The Long Walk": {"stop_sequence": "1", "latitude": "54.00573544", "longitude": "-6.404328583", "route_data": " 100, 100x, 160, 161, 162, 166, 167,  ... (4194 characters truncated) ... plate_code": "555101.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1is B\\u00c1 Luain", "atco_code": "8330B5551001"}}')
# 2022-07-02 21:10:47,922 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,923 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,923 INFO sqlalchemy.engine.Engine [raw sql] ('The Long Walk - Carlingford', 'The Long Walk', 'Carlingford', 'BE', '161', 'O', '{"The Long Walk": {"stop_sequence": "1", "latitude": "54.00573544", "longitude": "-6.404328583", "route_data": " 100, 100x, 160, 161, 162, 166, 167,  ... (6128 characters truncated) ... ate_code": "139871.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "S\\u00e9ip\\u00e9al Mhuire", "atco_code": "8300B139871"}}')
# 2022-07-02 21:10:47,924 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,925 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,925 INFO sqlalchemy.engine.Engine [raw sql] ('The Long Walk - Carrickmacross', 'The Long Walk', 'Carrickmacross', 'BE', '166', 'O', '{"The Long Walk": {"stop_sequence": "1", "latitude": "54.00573544", "longitude": "-6.404328583", "route_data": " 100, 100x, 160, 161, 162, 166, 167,  ... (2099 characters truncated) ... 6, 182", "plate_code": "109091.0", "has_pole": "Unknown", "has_shelter": "Unknown", "stop_name_ga": "Cg Mhachaire Rois", "atco_code": "8540B109091"}}')
# 2022-07-02 21:10:47,925 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,926 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,926 INFO sqlalchemy.engine.Engine [raw sql] ('The Long Walk - Cavan Bus Station', 'The Long Walk', 'Cavan Bus Station', 'BE', '166', 'O', '{"The Long Walk": {"stop_sequence": "1", "latitude": "54.00573544", "longitude": "-6.404328583", "route_data": " 100, 100x, 160, 161, 162, 166, 167,  ... (5119 characters truncated) ... 9, 109x, 166", "plate_code": "101571.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "PM Breffni", "atco_code": "8520B1015701"}}')
# 2022-07-02 21:10:47,927 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,928 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,928 INFO sqlalchemy.engine.Engine [raw sql] ('The Long Walk - Drogheda Bus Station', 'The Long Walk', 'Drogheda Bus Station', 'BE', '100', 'I', '{"The Long Walk": {"stop_sequence": "1", "latitude": "54.00573544", "longitude": "-6.404328583", "route_data": " 100, 100x, 160, 161, 162, 166, 167,  ... (8285 characters truncated) ...  190", "plate_code": "108341.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "B\\u00f3thar Brugha", "atco_code": "8300B108341"}}')
# 2022-07-02 21:10:47,929 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 21:10:47,930 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, startpoint, headsign, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s, %s, %s)
# 2022-07-02 21:10:47,930 INFO sqlalchemy.engine.Engine [raw sql] ('The Long Walk - Fatima', 'The Long Walk', 'Fatima', 'BE', '174A', 'O', '{"The Long Walk": {"stop_sequence": "1", "latitude": "54.00573544", "longitude": "-6.404328583", "route_data": " 100, 100x, 160, 161, 162, 166, 167,  ... (538 characters truncated) ... te_data": " 174a", "plate_code": "107971.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Fatima", "atco_code": "8300B1079701"}}')
# 2022-07-02 21:10:47,931 INFO sqlalchemy.engine.Engine COMMIT
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
