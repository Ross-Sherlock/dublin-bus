# %% [markdown]
# # This is a notebook for converting a static csv (which contains all bus routes and stops information) to an easy-to-use json file. This will be built into an stops API for displaying information relateed to stops on routes.

# %%
# import modules
import json
import pandas as pd
import numpy as np

# %%
# reaed csv as pandas dataframe
df = pd.read_csv("stops.csv")
df.reset_index()
df["RouteName"] = df["RouteName"].str.upper()
df = df. replace(np.nan, "Unknown", regex=True) 
df
# Out:
#                   ShapeId Operator  StopSequence RouteName  \
# 0      10-100-e19-1.253.O       BE             1       100
# 1      10-100-e19-1.253.O       BE             2       100
# 2      10-100-e19-1.253.O       BE             3       100
# 3      10-100-e19-1.253.O       BE             4       100
# 4      10-100-e19-1.253.O       BE             5       100
# ...                   ...      ...           ...       ...
# 78796   10-606-wbe-1.29.I     WFRD             4        W6
# 78797   10-606-wbe-1.29.I     WFRD             5        W6
# 78798   10-606-wbe-1.29.I     WFRD             6        W6
# 78799   10-606-wbe-1.29.I     WFRD             7        W6
# 78800   10-606-wbe-1.29.I     WFRD             8        W6
#
#                     RouteDescription Direction      AtcoCode PlateCode  \
# 0      Strand Street - The Long Walk         O   8240B100021  100021.0
# 1      Strand Street - The Long Walk         O  8240B1002801  100281.0
# 2      Strand Street - The Long Walk         O  8310B1326201  132621.0
# 3      Strand Street - The Long Walk         O  8300B1359501  135951.0
# 4      Strand Street - The Long Walk         O  8300B1316301  131631.0
# ...                              ...       ...           ...       ...
# 78796                      nan - nan         I   8440B352541  352541.0
# 78797                      nan - nan         I   8440B352551  352551.0
# 78798                      nan - nan         I  8440B3525801  352581.0
# 78799                      nan - nan         I  8440B3525901  352591.0
# 78800                      nan - nan         I   8440B886521   Unknown
#
#         Latitude Longitude    ShortCommonName_en   ShortCommonName_ga  \
# 0       53.58039  -6.10701         Strand Street         Sráid na Trá
# 1      53.604482 -6.184453     St Paul's Cresent         Corrán N Pól
# 2      53.674204 -6.286549          Laytown Road      Bóthar na hInse
# 3      53.711722 -6.353395  Drogheda Bus Station         Stáisiún Bus
# 4      53.825306 -6.394606               Dunleer            Dún Léire
# ...          ...       ...                   ...                  ...
# 78796  52.258168 -7.110039        Parnell Street        Sráid Parnell
# 78797  52.259724  -7.10658     Waterford Crystal  Criostail Pt Láirge
# 78798  52.261859   -7.1108        Meagher's Quay         Cé Mheachair
# 78799  52.263113  -7.11621        Merchants Quay    Cé na gCeannaithe
# 78800    Unknown   Unknown               Unknown              Unknown
#
#        HasPole  HasShelter   CarouselType   FlagData  \
# 0      No Pole  No Shelter           None       None
# 1      No Pole     Shelter           None       None
# 2      No Pole     Shelter           None       None
# 3      No Pole  No Shelter           None       None
# 4         Pole  No Shelter           None   Circular
# ...        ...         ...            ...        ...
# 78796  No Pole     Shelter  Shelter Panel   Circular
# 78797     Pole  No Shelter           None  Stretched
# 78798  No Pole     Shelter  Shelter Panel  Stretched
# 78799  No Pole  No Shelter           None   Circular
# 78800  Unknown     Unknown        Unknown    Unknown
#
#                                                RouteData
# 0                                                    100
# 1                                         100, 101, 101x
# 2                                    100, 101, 101x, 912
# 3       100, 100x, 101, 101x, 105, 163, 168, 182, 182...
# 4                                              100, 100x
# ...                                                  ...
# 78796                 360, 360a, 362, 40, w2, w3, w5, w6
# 78797                              360, 360a, w2, w5, w6
# 78798           360, 360a, 609, 610, 611, w2, w3, w5, w6
# 78799                                736, w2, w4, w5, w6
# 78800                                                 w6
#
# [78801 rows x 17 columns]

# %%
df = df.convert_dtypes()
df["StopSequence"] = df["StopSequence"].astype('string')
df["PlateCode"] = df["PlateCode"].astype('string')
df["Latitude"] = df["Latitude"].astype('string')
df["Longitude"] = df["Longitude"].astype('string')
df.dtypes
# Out:
# ShapeId               string
# Operator              string
# StopSequence          string
# RouteName             string
# RouteDescription      string
# Direction             string
# AtcoCode              string
# PlateCode             string
# Latitude              string
# Longitude             string
# ShortCommonName_en    string
# ShortCommonName_ga    string
# HasPole               string
# HasShelter            string
# CarouselType          string
# FlagData              string
# RouteData             string
# dtype: object

# %%
#drop two columns
df = df.drop(columns=["ShapeId", "CarouselType", "FlagData"])
df.count()
# Out:
# Operator              78801
# StopSequence          78801
# RouteName             78801
# RouteDescription      78801
# Direction             78801
# AtcoCode              78801
# PlateCode             78801
# Latitude              78801
# Longitude             78801
# ShortCommonName_en    78801
# ShortCommonName_ga    78801
# HasPole               78801
# HasShelter            78801
# RouteData             78801
# dtype: int64

# %%
# drop duplicated rows (same stops)
df = df.drop_duplicates(keep='first')

# %%
# group by 'RouteDescription'
df2 = df.groupby(["RouteDescription"])
df2.count()
# Out:
#                                 Operator  StopSequence  RouteName  Direction  \
# RouteDescription
# Abbey Road - Athlone Station          10            10         10         10
# Abbey Road - Cavan Bus Station        25            25         25         25
# Abbey Road - DCU                       6             6          6          6
# Abbey Road - Kells                    11            11         11         11
# Abbey Road - Kingscourt               10            10         10         10
# ...                                  ...           ...        ...        ...
# nan - St Patrick's Street              4             4          4          4
# nan - Wexford Station                 24            24         24         24
# nan - Whitegate                       13            13         13         13
# nan - Wilton Terrace                  18            18         18         18
# nan - nan                             39            39         39         39
#
#                                 AtcoCode  PlateCode  Latitude  Longitude  \
# RouteDescription
# Abbey Road - Athlone Station          10         10        10         10
# Abbey Road - Cavan Bus Station        25         25        25         25
# Abbey Road - DCU                       6          6         6          6
# Abbey Road - Kells                    11         11        11         11
# Abbey Road - Kingscourt               10         10        10         10
# ...                                  ...        ...       ...        ...
# nan - St Patrick's Street              4          4         4          4
# nan - Wexford Station                 24         24        24         24
# nan - Whitegate                       13         13        13         13
# nan - Wilton Terrace                  18         18        18         18
# nan - nan                             39         39        39         39
#
#                                 ShortCommonName_en  ShortCommonName_ga  \
# RouteDescription
# Abbey Road - Athlone Station                    10                  10
# Abbey Road - Cavan Bus Station                  25                  25
# Abbey Road - DCU                                 6                   6
# Abbey Road - Kells                              11                  11
# Abbey Road - Kingscourt                         10                  10
# ...                                            ...                 ...
# nan - St Patrick's Street                        4                   4
# nan - Wexford Station                           24                  24
# nan - Whitegate                                 13                  13
# nan - Wilton Terrace                            18                  18
# nan - nan                                       39                  39
#
#                                 HasPole  HasShelter  RouteData
# RouteDescription
# Abbey Road - Athlone Station         10          10         10
# Abbey Road - Cavan Bus Station       25          25         25
# Abbey Road - DCU                      6           6          6
# Abbey Road - Kells                   11          11         11
# Abbey Road - Kingscourt              10          10         10
# ...                                 ...         ...        ...
# nan - St Patrick's Street             4           4          4
# nan - Wexford Station                24          24         24
# nan - Whitegate                      13          13         13
# nan - Wilton Terrace                 18          18         18
# nan - nan                            39          39         39
#
# [1284 rows x 13 columns]

# %%
# store all route descriptions in a list
route_list= list(df2.groups.keys())
print(route_list)
# Out:
# ['Abbey Road - Athlone Station', 'Abbey Road - Cavan Bus Station', 'Abbey Road - DCU', 'Abbey Road - Kells', 'Abbey Road - Kingscourt', "Abbey Road - O'Connel Street", 'Abbey Road - UCD Belfield Campus', 'Abbey Road - Wilton Terrace', 'Abbey St Lower - Clontarf Castle', 'Abbey St Lower - Mourne View', 'Abbey St Lower - Peter & Paul Church', 'Abbey St Lower - Red Arches Rd', 'Abbey Street - Colbert Station', 'Abbey Street - Dromkeen', 'Abbeyfeale - Casement Station', 'Abbeyfeale - Killarney Bus Stn', 'Adamstown Station - Merrion Sq South', 'Aisling Place - Commons Road', 'Alverno Terrace - Drogheda Bus Station', 'Annagassan - Drogheda Bus Station', 'Annagassan - The Long Walk', 'Apple Inc - Mahon Point SC', 'Apple Inc - Merchants Quay', 'Ardee Bypass - Drogheda Bus Station', 'Ardee Lidl - The Long Walk', 'Ardmore - Parnell Place', 'Ardmore - Youghal', 'Ardnacrusha - Arthurs Quay', 'Ardnacrusha - Colbert Station', 'Arklow - Custom House Quay', 'Arthurs Quay - Ardnacrusha', 'Arthurs Quay - St Nicholas Church', 'Ash Lane - Busáras', 'Ash Lane - Coolaney', 'Ashington Park - Drimnagh PO', 'Ashington Park - Parnell Square East', 'Ashleigh Green - Wilton Terrace', 'Ashmount Terminus - Curraheen Village', 'Ashmount Terminus - Marymount Hospice', "Ashmount Terminus - St Patrick's Street", 'Aston Quay - Park West Hotel', 'Aston Quay - Spiddal Park', 'Aston Quay - Woodford Hill', 'Aston Village - Deepforde Estate', 'Aston Village - Wilton Terrace', 'Athboy - Busáras', 'Athboy - Cavan Bus Station', 'Athboy - UCD Belfield Campus', 'Athlone Station - Abbey Road', 'Athlone Station - Castle Street', 'Athlone Station - Claremorris', 'Athlone Station - Colbert Station', 'Athlone Station - Longford Station', 'Athlone Station - Mart Road', 'Athlone Station - Mill Street', 'Athlone Station - Monaghan Bus Stn', 'Athlone Station - Mullingar Station', 'Athlone Station - The Long Walk', 'Athlone Station - Waterford Bus Stn', 'Aulden Grange - Eden Quay', 'Bailieborough - Kells', 'Balbriggan Station - Millfield Centre', 'Balbriggan Station - The Hastings', 'Baldoyle Church - Abbey St Lower', 'Balgaddy Road - East Road', 'Balgaddy Road - Eden Quay', 'Balgriffin Cottages - Sutton Park School', 'Ballaghaderreen - Galway Bus Station', 'Ballentree Avenue - Scoil Oilibheir', 'Ballina Station - Ballina Station', 'Ballina Station - Ballycastle', 'Ballina Station - Belmullet', 'Ballina Station - Busáras', 'Ballina Station - Claremorris', 'Ballina Station - Creggs Road Cross', 'Ballina Station - Dromore West', 'Ballina Station - Dublin Airport', 'Ballina Station - Enniskillen', 'Ballina Station - Galway Bus Station', 'Ballina Station - IT Sligo', 'Ballina Station - Killala', 'Ballina Station - Longford Station', 'Ballina Station - Main Street Swinford', 'Ballina Station - Market Square', 'Ballina Station - Mill Street', 'Ballina Station - Moygownagh', 'Ballina Station - Sligo Bus Station', 'Ballina Station - Stephen Garvey Way', 'Ballina Station - nan', 'Ballinacurra - Parnell Place', 'Ballinastack - Galway Bus Station', 'Ballintra - Donegal Town Centre', 'Ballybane Ind Estate - Eyre Square', 'Ballybane Ind Estate - Gort na Bro', 'Ballyboden Church - Parnell Square East', 'Ballybofey - Canal Street', 'Ballybofey - Letterkenny Station', 'Ballybofey - Ulsterbus Depot', 'Ballybrack Road - Dundrum Luas', 'Ballybunion - Casement Station', 'Ballycastle - Ballina Station', 'Ballycastle - Dunnes Stores', 'Ballycotton - Parnell Place', 'Ballycotton - nan', 'Ballycullen Road - Clongriffin Station', 'Ballyheigue - Casement Station', 'Ballyjamesduff - Kells', 'Ballymote - Sligo Bus Station', 'Ballymote - Wolfe Tone Square', 'Ballyshannon - Manorhamilton', 'Ballyshannon - Sligo Bus Station', 'Baltimore - Skibbereen', 'Bantry - Glengarriff', 'Bantry - Parnell Place', 'Bargy Road - Foxborough Estate', 'Barons Hall Grove - The Hastings', 'Bealnamulla - Kilmartin Centre', 'Beaumont Hospital - DCU Helix', 'Beechfield Manor - Mountjoy Square', 'Beechpark Estate - UCD', 'Belarmine -  ...

# %%
#use 46A for testing
test_group = df2.get_group("Brewery Road - Phoenix Park")
test_group.head()
# Out:
#       Operator StopSequence RouteName             RouteDescription Direction  \
# 59698       DB            1       46A  Brewery Road - Phoenix Park         I
# 59699       DB            2       46A  Brewery Road - Phoenix Park         I
# 59700       DB            3       46A  Brewery Road - Phoenix Park         I
# 59701       DB            4       46A  Brewery Road - Phoenix Park         I
# 59702       DB            5       46A  Brewery Road - Phoenix Park         I
#
#            AtcoCode PlateCode     Latitude     Longitude   ShortCommonName_en  \
# 59698  8250DB002064    2064.0  53.28272564  -6.193849161         Brewery Road
# 59699  8250DB002065    2065.0  53.28479921   -6.19485659        Merville Road
# 59700  8250DB004727    4727.0  53.29081171   -6.19778321        Laurence Park
# 59701  8250DB004728    4728.0  53.29333789  -6.201982289     Oatlands College
# 59702  8250DB000461     461.0   53.2947995  -6.203541111  Stillorgan Pk Hotel
#
#         ShortCommonName_ga  HasPole  HasShelter  \
# 59698  Bóthar na Grúdlanne  No Pole     Shelter
# 59699      Bóthar Merville  No Pole     Shelter
# 59700    Páirc San Labhrás  No Pole     Shelter
# 59701    Col Fhearann Dara  No Pole  No Shelter
# 59702  Óstán Stillorgan Pk     Pole  No Shelter
#
#                                                RouteData
# 59698                   118, 145, 155, 46a, 75, 75a, 84x
# 59699                        118, 145, 155, 46a, 75, 75a
# 59700   116, 118, 133, 133x, 145, 155, 181, 46a, 46e,...
# 59701           116, 118, 145, 155, 46a, 46e, 47, 7b, 7d
# 59702   116, 118, 145, 155, 46a, 46e, 47, 740, 740a, ...

# %%
# get route name
route_name = test_group['RouteName'].iloc[0]
print(route_name)

# get bus operator
operator = test_group['Operator'].iloc[0]
print(operator)

# get direction indicator
direction = test_group['Direction'].iloc[0]
print(direction)

# get the whole row, here first row as example
first_row = test_group.iloc[0]
print(first_row)

# get len (number of rows) of the group
print(len(test_group))
# Out:
# 46A
# DB
# I
# Operator                                             DB
# StopSequence                                          1
# RouteName                                           46A
# RouteDescription            Brewery Road - Phoenix Park
# Direction                                             I
# AtcoCode                                   8250DB002064
# PlateCode                                        2064.0
# Latitude                                    53.28272564
# Longitude                                  -6.193849161
# ShortCommonName_en                         Brewery Road
# ShortCommonName_ga                  Bóthar na Grúdlanne
# HasPole                                         No Pole
# HasShelter                                      Shelter
# RouteData              118, 145, 155, 46a, 75, 75a, 84x
# Name: 59698, dtype: string
# 41

# %%
# define a function for appending all data to a single python dictionary
def get_route_info(dataframe, RouteDescription):
    sub_group = dataframe.get_group(RouteDescription)

    operator = sub_group['Operator'].iloc[0]
    route_name = sub_group['RouteName'].iloc[0]
    direction = sub_group['Direction'].iloc[0]

    stops = {}
    for i in range(len(sub_group)):
        single_row = sub_group.iloc[i]
        stop_name_en = single_row['ShortCommonName_en']
        stop_name_ga = single_row['ShortCommonName_ga']
        stop_sequence = single_row['StopSequence']
        atco_code = single_row['AtcoCode']
        plate_code = single_row['PlateCode']
        latitude = single_row['Latitude']
        longitude = single_row['Longitude']
        has_pole = single_row['HasPole']
        has_shelter = single_row['HasShelter']
        route_data = single_row['RouteData']

        stops[stop_name_en] = {
            "stop_sequence": stop_sequence,
            "latitude": latitude,
            "longitude": longitude,
            "route_data": route_data,
            "plate_code":  plate_code, 
            "has_pole": has_pole,
            "has_shelter": has_shelter,
            "stop_name_ga": stop_name_ga,
            "atco_code": atco_code
        }

    results = {
        "operator": operator,
        "route_name": route_name,
        "direction": direction,
        "stops": stops
    }

    return results

# %%
# create an empty dict to store all data
data = {}

# iterate the route_list and append all details to the dictionary
for route in route_list:
    route_info = get_route_info(df2, route)
    data[route] = {
        "Operator": route_info['operator'],
        "RouteName": route_info['route_name'],
        "Direction": route_info['direction'],
        "stops": route_info['stops']
    }

print(data['Abbey Road - Athlone Station'])
# Out:
# {'Operator': 'BE', 'RouteName': '70', 'Direction': 'I', 'stops': {'Abbey Road': {'stop_sequence': '1', 'latitude': '53.65469707', 'longitude': '-6.684807484', 'route_data': ' 107, 109, 109a, 190', 'plate_code': '138451.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Br na Mainistreach', 'atco_code': '8310B138451'}, 'Athboy': {'stop_sequence': '2', 'latitude': '53.62189877', 'longitude': '-6.9206792', 'route_data': ' 111, 111a, 111x', 'plate_code': '135891.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Baile Átha Buí', 'atco_code': '8310B1358901'}, 'Delvin': {'stop_sequence': '3', 'latitude': '53.61180518', 'longitude': '-7.092692547', 'route_data': ' 111a, 111x', 'plate_code': '131771.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Dealbhna', 'atco_code': '8330B1317701'}, 'Castle Street': {'stop_sequence': '4', 'latitude': '53.52651374', 'longitude': '-7.340037477', 'route_data': ' 115, 115c, 22, 23, 70, 837, 842', 'plate_code': '135761.0', 'has_pole': 'Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Sráid an Chaisleáin', 'atco_code': '8330B1357601'}, 'Unknown': {'stop_sequence': '5', 'latitude': 'Unknown', 'longitude': 'Unknown', 'route_data': '70', 'plate_code': 'Unknown', 'has_pole': 'Unknown', 'has_shelter': 'Unknown', 'stop_name_ga': 'Unknown', 'atco_code': '8330B152171'}, 'Kilbeggan Square': {'stop_sequence': '6', 'latitude': '53.36810653', 'longitude': '-7.498186381', 'route_data': ' 20, 70, 763', 'plate_code': '155441.0', 'has_pole': 'Pole', 'has_shelter': 'Shelter', 'stop_name_ga': 'Crng Chill Bheagáin', 'atco_code': '8330B1554401'}, 'Horseleap': {'stop_sequence': '7', 'latitude': '53.39247683', 'longitude': '-7.581520982', 'route_data': '70', 'plate_code': '152321.0', 'has_pole': 'No Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'B Átha an Urchair', 'atco_code': '8330B1523201'}, 'Moate': {'stop_sequence': '8', 'latitude': '53.39521799', 'longitude': '-7.719803662', 'route_data': ' 20, 70, 73, 763', 'plate_code': '155431.0', 'has_pole': 'Pole', 'has_shelter': 'Shelter', 'stop_name_ga': 'An Móta', 'atco_code': '8330B1554301'}, 'Athlone AIT': {'stop_sequence': '9', 'latitude': '53.41557214', 'longitude': '-7.899592102', 'route_data': ' 20, 70, 72, 73, 763, a1, a2, x20', 'plate_code': '455591.0', 'has_pole': 'Unknown', 'has_shelter': 'Unknown', 'stop_name_ga': 'ITBAL Átha Luain', 'atco_code': '8330B455591'}, 'Athlone Station': {'stop_sequence': '10', 'latitude': '53.42658765', 'longitude': '-7.935225814', 'route_data': ' 20, 440, 461, 466, 65, 70, 72, 73, x20', 'plate_code': '555101.0', 'has_pole': 'Pole', 'has_shelter': 'No Shelter', 'stop_name_ga': 'Stáis BÁ Luain', 'atco_code': '8330B5551001'}}}

# %%
# # finally convert the dict to json 
# json_result = json.dumps(data)
# print(json_result[:1000])

# %% [markdown]
# # Next store static data to MySQL database

# %%
from sqlalchemy import create_engine

# %%
# a method for connecting to db
def engine():
    return create_engine(
        "mysql+pymysql://{}:{}@{}:{}/{}".format(
                        "root",
                        "password here",
                        "localhost",
                        3306,
                        "dublinbus"), echo=True)

# %%
# a method for creating the table
def create_table(engine):
    sql1 = """
    CREATE TABLE IF NOT EXISTS static_stops 
    (
        route_description VARCHAR(50),
        operator VARCHAR(10), 
        route_name VARCHAR(10), 
        direction VARCHAR(4),
        stops JSON
    );
    """

    #execute sql
    try:
        print("creating table static_stops ...")
        engine.execute(sql1)
    except Exception as e:
        print(e)

create_table(engine())
# Out:
# creating table static_stops ...
# 2022-07-02 14:54:02,239 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-07-02 14:54:02,239 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 14:54:02,240 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-07-02 14:54:02,240 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 14:54:02,241 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-07-02 14:54:02,241 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 14:54:02,243 INFO sqlalchemy.engine.Engine
#     CREATE TABLE IF NOT EXISTS static_stops
#     (
#         route_description VARCHAR(50),
#         operator VARCHAR(10),
#         route_name VARCHAR(10),
#         direction VARCHAR(4),
#         stops JSON
#     );
#
# 2022-07-02 14:54:02,243 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 14:54:02,251 INFO sqlalchemy.engine.Engine COMMIT

# %%
def insert (engine, route_list, data):
    for route in route_list:
        operator = data[route]['Operator']
        route_name = data[route]['RouteName']
        direction = data[route]['Direction']
        stops = json.dumps(data[route]['stops'])
        
        engine.execute(
            "INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)", (route, operator, route_name, direction, stops)
        )

    
insert(engine=engine(), route_list=route_list, data=data)
# Out:
# 2022-07-02 14:54:02,282 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-07-02 14:54:02,283 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 14:54:02,284 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-07-02 14:54:02,284 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 14:54:02,285 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-07-02 14:54:02,285 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-02 14:54:02,286 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,287 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Athlone Station', 'BE', '70', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (2434 characters truncated) ... plate_code": "555101.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1is B\\u00c1 Luain", "atco_code": "8330B5551001"}}')
# 2022-07-02 14:54:02,289 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,290 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,291 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Cavan Bus Station', 'BE', '109', 'O', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (6537 characters truncated) ...  "plate_code": "135861.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St Bus an Chabh\\u00e1in", "atco_code": "8520B1358601"}}')
# 2022-07-02 14:54:02,292 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,294 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,294 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - DCU', 'BE', '109A', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (1296 characters truncated) ... route_data": " 109a", "plate_code": "135021.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "DCU", "atco_code": "8220B1350201"}}')
# 2022-07-02 14:54:02,296 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,297 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,297 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Kells', 'BE', '107', 'O', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (2322 characters truncated) ... 9a, 109x, 187", "plate_code": "135391.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Ceanannas", "atco_code": "8310B1353901"}}')
# 2022-07-02 14:54:02,298 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,300 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,300 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Kingscourt', 'BE', '107', 'O', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65469707", "longitude": "-6.684807484", "route_data": " 107, 109, 109a, 190", "plate_code": "13 ... (2051 characters truncated) ...  "plate_code": "137831.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "D\\u00fan an R\\u00ed", "atco_code": "8520B1378301"}}')
# 2022-07-02 14:54:02,302 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,303 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,303 INFO sqlalchemy.engine.Engine [raw sql] ("Abbey Road - O'Connel Street", 'BE', 'NX', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65443787", "longitude": "-6.684119643", "route_data": " 103x, 109x, nx", "plate_code": "138461. ... (2481 characters truncated) ... te_code": "135051.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sr\\u00e1id U\\u00ed Chonaill", "atco_code": "8220B1350501"}}')
# 2022-07-02 14:54:02,305 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,306 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,306 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - UCD Belfield Campus', 'BE', '103X', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65443787", "longitude": "-6.684119643", "route_data": " 103x, 109x, nx", "plate_code": "138461. ... (3951 characters truncated) ... 115, 180", "plate_code": "135061.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "COB\\u00c1C", "atco_code": "8250B1350601"}}')
# 2022-07-02 14:54:02,308 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,309 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,309 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Road - Wilton Terrace', 'BE', 'NX', 'I', '{"Abbey Road": {"stop_sequence": "1", "latitude": "53.65443787", "longitude": "-6.684119643", "route_data": " 103x, 109x, nx", "plate_code": "138461. ... (3574 characters truncated) ... nx", "plate_code": "135411.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ard\\u00e1n Wilton", "atco_code": "8220B135411"}}')
# 2022-07-02 14:54:02,310 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,311 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,312 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Clontarf Castle', 'DB', '130', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34889015", "longitude": "-6.256829774", "route_data": "130", "plate_code": "7591.0", "has_p ... (9676 characters truncated) ... 4, 130", "plate_code": "1767.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cais Chluain Tarbh", "atco_code": "8220DB001767"}}')
# 2022-07-02 14:54:02,314 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,315 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,315 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Mourne View', 'DB', '33', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34919969", "longitude": "-6.255254959", "route_data": " 33, 33e", "plate_code": "292.0", "h ... (29558 characters truncated) ...  " 33a, 33e, 33x", "plate_code": "5176.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Reilg", "atco_code": "8240DB005176"}}')
# 2022-07-02 14:54:02,319 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,321 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,321 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Peter & Paul Church', 'DB', '33', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34919969", "longitude": "-6.255254959", "route_data": " 33, 33e", "plate_code": "292.0", "h ... (27325 characters truncated) ...  33x", "plate_code": "7174.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Peadair & P\\u00f3il", "atco_code": "8240DB007174"}}')
# 2022-07-02 14:54:02,325 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,326 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,326 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey St Lower - Red Arches Rd', 'DB', '29A', 'O', '{"Abbey St Lower": {"stop_sequence": "1", "latitude": "53.34903518", "longitude": "-6.256298123", "route_data": " 29a, 31, 31a, 31b, 32", "plate_code ... (11564 characters truncated) ... ate_code": "938.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br na n\\u00c1irs\\u00ed Dearga", "atco_code": "8240DB000938"}}')
# 2022-07-02 14:54:02,329 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,330 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,330 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Street - Colbert Station', 'BE', '347', 'I', '{"Abbey Street": {"stop_sequence": "1", "latitude": "52.4726851", "longitude": "-8.161024295", "route_data": " 347, 55", "plate_code": "331851.0", "h ... (1338 characters truncated) ... e_code": "635031.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "St\\u00e1isi\\u00fan Cholbaird", "atco_code": "8400B6350301"}}')
# 2022-07-02 14:54:02,331 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,332 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,333 INFO sqlalchemy.engine.Engine [raw sql] ('Abbey Street - Dromkeen', 'BE', '347', 'I', '{"Abbey Street": {"stop_sequence": "1", "latitude": "52.4726851", "longitude": "-8.161024295", "route_data": " 347, 55", "plate_code": "331851.0", "h ... (975 characters truncated) ... a": " 347, 55", "plate_code": "331801.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Drom Caoin", "atco_code": "8410B331801"}}')
# 2022-07-02 14:54:02,334 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,335 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,335 INFO sqlalchemy.engine.Engine [raw sql] ('Abbeyfeale - Casement Station', 'BE', '13', 'O', '{"Abbeyfeale": {"stop_sequence": "1", "latitude": "52.38654882", "longitude": "-9.295100275", "route_data": " 13, 14, 271, 300", "plate_code": "63566 ... (2731 characters truncated) ... "plate_code": "600091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "IT Thr\\u00e1 L\\u00ed", "atco_code": "8390B6000901"}}')
# 2022-07-02 14:54:02,336 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,337 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,338 INFO sqlalchemy.engine.Engine [raw sql] ('Abbeyfeale - Killarney Bus Stn', 'BE', '14', 'O', '{"Abbeyfeale": {"stop_sequence": "1", "latitude": "52.38654882", "longitude": "-9.295100275", "route_data": " 13, 14, 271, 300", "plate_code": "63566 ... (1643 characters truncated) ... , "plate_code": "635601.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "St\\u00e1is Chill Airne", "atco_code": "8390B6356001"}}')
# 2022-07-02 14:54:02,339 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,340 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,341 INFO sqlalchemy.engine.Engine [raw sql] ('Adamstown Station - Merrion Sq South', 'DB', '25B', 'I', '{"Adamstown Station": {"stop_sequence": "1", "latitude": "53.33620092", "longitude": "-6.468505098", "route_data": " 25b", "plate_code": "6290.0", "h ... (11645 characters truncated) ... 6x, 67x", "plate_code": "7049.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "P\\u00e1irc Vesey", "atco_code": "8230DB007049"}}')
# 2022-07-02 14:54:02,343 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,344 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,344 INFO sqlalchemy.engine.Engine [raw sql] ('Aisling Place - Commons Road', 'BE', 'N2', 'I', '{"Aisling Place": {"stop_sequence": "1", "latitude": "53.66381724", "longitude": "-6.676488506", "route_data": " n2", "plate_code": "189311.0", "has_ ... (4688 characters truncated) ... ate_code": "189001.0", "has_pole": "Unknown", "has_shelter": "Unknown", "stop_name_ga": "B\\u00f3thar an Choim\\u00edn", "atco_code": "8310B189001"}}')
# 2022-07-02 14:54:02,346 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,347 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,347 INFO sqlalchemy.engine.Engine [raw sql] ('Alverno Terrace - Drogheda Bus Station', 'BE', 'D1', 'I', '{"Alverno Terrace": {"stop_sequence": "1", "latitude": "53.67856622", "longitude": "-6.240261146", "route_data": " 910, d1, d2", "plate_code": "10933 ... (4346 characters truncated) ... "111791.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Pl\\u00e1s\\u00f3ga Na M\\u00ednleach", "atco_code": "8310B111791"}}')
# 2022-07-02 14:54:02,348 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,349 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,349 INFO sqlalchemy.engine.Engine [raw sql] ('Annagassan - Drogheda Bus Station', 'BE', '168', 'O', '{"Annagassan": {"stop_sequence": "1", "latitude": "53.88236537", "longitude": "-6.342998952", "route_data": "168", "plate_code": "107041.0", "has_pol ... (2987 characters truncated) ... late_code": "135951.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1isi\\u00fan Bus", "atco_code": "8300B1359501"}}')
# 2022-07-02 14:54:02,350 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,351 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,352 INFO sqlalchemy.engine.Engine [raw sql] ('Annagassan - The Long Walk', 'BE', '168', 'I', '{"Annagassan": {"stop_sequence": "1", "latitude": "53.88220075", "longitude": "-6.342792505", "route_data": "168", "plate_code": "109661.0", "has_pol ... (3060 characters truncated) ... te_code": "105091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Si\\u00fal\\u00e1n Fada", "atco_code": "8300B1050901"}}')
# 2022-07-02 14:54:02,353 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,354 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,354 INFO sqlalchemy.engine.Engine [raw sql] ('Apple Inc - Mahon Point SC', 'BE', '202', 'I', '{"Apple Inc": {"stop_sequence": "1", "latitude": "51.9053791", "longitude": "-8.51533124", "route_data": " 201, 202, 202a", "plate_code": "298951.0", ... (11683 characters truncated) ... 212, 219", "plate_code": "246851.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br Rinn Mhachan", "atco_code": "8370B246851"}}')
# 2022-07-02 14:54:02,356 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,358 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,358 INFO sqlalchemy.engine.Engine [raw sql] ('Apple Inc - Merchants Quay', 'BE', '202', 'I', '{"Apple Inc": {"stop_sequence": "1", "latitude": "51.9053791", "longitude": "-8.51533124", "route_data": " 201, 202, 202a", "plate_code": "298951.0", ... (4591 characters truncated) ... ", "plate_code": "299021.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "C\\u00e9 na gCeannaithe", "atco_code": "8370B299021"}}')
# 2022-07-02 14:54:02,359 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,360 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,361 INFO sqlalchemy.engine.Engine [raw sql] ('Ardee Bypass - Drogheda Bus Station', 'BE', '182A', 'I', '{"Ardee Bypass": {"stop_sequence": "1", "latitude": "53.86472765", "longitude": "-6.541312241", "route_data": " 180, 182, 182a, 32", "plate_code": "1 ... (1923 characters truncated) ... late_code": "135951.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1isi\\u00fan Bus", "atco_code": "8300B1359501"}}')
# 2022-07-02 14:54:02,362 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,363 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,364 INFO sqlalchemy.engine.Engine [raw sql] ('Ardee Lidl - The Long Walk', 'BE', '167', 'I', '{"Ardee Lidl": {"stop_sequence": "1", "latitude": "53.84548081", "longitude": "-6.538638058", "route_data": " 167, 182, 182a", "plate_code": "109461. ... (2411 characters truncated) ... te_code": "105091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Si\\u00fal\\u00e1n Fada", "atco_code": "8300B1050901"}}')
# 2022-07-02 14:54:02,365 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,366 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,366 INFO sqlalchemy.engine.Engine [raw sql] ('Ardmore - Parnell Place', 'BE', '260', 'I', '{"Ardmore": {"stop_sequence": "1", "latitude": "51.95089685", "longitude": "-7.724573629", "route_data": "260", "plate_code": "244601.0", "has_pole": ... (9227 characters truncated) ... "260", "plate_code": "232771.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br Dhr na Scuab", "atco_code": "8380B2327701"}}')
# 2022-07-02 14:54:02,368 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,369 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,370 INFO sqlalchemy.engine.Engine [raw sql] ('Ardmore - Youghal', 'BE', '260', 'I', '{"Ardmore": {"stop_sequence": "1", "latitude": "51.95089685", "longitude": "-7.724573629", "route_data": "260", "plate_code": "244601.0", "has_pole": ... (1270 characters truncated) ... ta": " 260, 40", "plate_code": "216341.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Eochaill", "atco_code": "8380B2163401"}}')
# 2022-07-02 14:54:02,371 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,373 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,373 INFO sqlalchemy.engine.Engine [raw sql] ('Ardnacrusha - Arthurs Quay', 'BE', '313', 'I', '{"Ardnacrusha": {"stop_sequence": "1", "latitude": "52.70694665", "longitude": "-8.618718342", "route_data": "313", "plate_code": "332061.0", "has_po ... (1555 characters truncated) ... 5", "plate_code": "605551.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "C\\u00e9 Art\\u00fair", "atco_code": "8400B6055501"}}')
# 2022-07-02 14:54:02,374 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,374 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,375 INFO sqlalchemy.engine.Engine [raw sql] ('Ardnacrusha - Colbert Station', 'BE', '313', 'I', '{"Ardnacrusha": {"stop_sequence": "1", "latitude": "52.70694665", "longitude": "-8.618718342", "route_data": "313", "plate_code": "332061.0", "has_po ... (3237 characters truncated) ... 313", "plate_code": "606741.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Bruach na Sionainne", "atco_code": "8360B6067401"}}')
# 2022-07-02 14:54:02,376 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,377 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,377 INFO sqlalchemy.engine.Engine [raw sql] ('Arklow - Custom House Quay', 'BE', '133', 'I', '{"Arklow": {"stop_sequence": "1", "latitude": "52.79835209", "longitude": "-6.156799695", "route_data": " 133, 133l, 133x, 2", "plate_code": "135531. ... (4409 characters truncated) ... late_code": "101971.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "C\\u00e9 Thch an Chustaim", "atco_code": "8220B101971"}}')
# 2022-07-02 14:54:02,378 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,380 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,380 INFO sqlalchemy.engine.Engine [raw sql] ('Arthurs Quay - Ardnacrusha', 'BE', '313', 'O', '{"Arthurs Quay": {"stop_sequence": "1", "latitude": "52.66530072", "longitude": "-8.626364536", "route_data": " 313, 315", "plate_code": "605551.0",  ... (3156 characters truncated) ... , "plate_code": "333781.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cnoc na Ghi\\u00faise", "atco_code": "8360B333781"}}')
# 2022-07-02 14:54:02,382 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,383 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,384 INFO sqlalchemy.engine.Engine [raw sql] ('Arthurs Quay - St Nicholas Church', 'BE', '301', 'O', '{"Arthurs Quay": {"stop_sequence": "1", "latitude": "52.66511135", "longitude": "-8.626480098", "route_data": " 301, 323, 323x, 341, 345", "plate_cod ... (4011 characters truncated) ... e": "606721.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "S\\u00e9ip\\u00e9al San Nicholas", "atco_code": "8360B6067201"}}')
# 2022-07-02 14:54:02,385 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,386 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,387 INFO sqlalchemy.engine.Engine [raw sql] ('Ash Lane - Busáras', 'BE', '23', 'I', '{"Ash Lane": {"stop_sequence": "1", "latitude": "54.27620448", "longitude": "-8.460225326", "route_data": " 23, 462, 475", "plate_code": "524861.0",  ... (6179 characters truncated) ... 30, x4", "plate_code": "111911.0", "has_pole": "Unknown", "has_shelter": "Unknown", "stop_name_ga": "Aerfort B\\u00c1C", "atco_code": "8240B111911"}}')
# 2022-07-02 14:54:02,389 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,391 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,391 INFO sqlalchemy.engine.Engine [raw sql] ('Ash Lane - Coolaney', 'BE', '475', 'O', '{"Ash Lane": {"stop_sequence": "1", "latitude": "54.27620448", "longitude": "-8.460225326", "route_data": " 23, 462, 475", "plate_code": "524861.0",  ... (2442 characters truncated) ... 5", "plate_code": "556441.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "C\\u00fail \\u00c1ine", "atco_code": "8510B5564401"}}')
# 2022-07-02 14:54:02,392 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,394 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,394 INFO sqlalchemy.engine.Engine [raw sql] ('Ashington Park - Drimnagh PO', 'DB', '122', 'O', '{"Ashington Park": {"stop_sequence": "1", "latitude": "53.37344814", "longitude": "-6.311390924", "route_data": "122", "plate_code": "4525.0", "has_p ... (13745 characters truncated) ... 122, 123", "plate_code": "6094.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "OP Dhroimeanaigh", "atco_code": "8220DB006094"}}')
# 2022-07-02 14:54:02,397 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,398 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,399 INFO sqlalchemy.engine.Engine [raw sql] ('Ashington Park - Parnell Square East', 'DB', '122', 'O', '{"Ashington Park": {"stop_sequence": "1", "latitude": "53.37344814", "longitude": "-6.311390924", "route_data": "122", "plate_code": "4525.0", "has_p ... (5626 characters truncated) ... 0, 122, 9", "plate_code": "263.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cg Parnell Thoir", "atco_code": "8220DB000263"}}')
# 2022-07-02 14:54:02,401 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,402 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,403 INFO sqlalchemy.engine.Engine [raw sql] ('Ashleigh Green - Wilton Terrace', 'DB', '37', 'I', '{"Ashleigh Green": {"stop_sequence": "1", "latitude": "53.37958851", "longitude": "-6.367711534", "route_data": " 37, 38", "plate_code": "1687.0", "h ... (10884 characters truncated) ... "37", "plate_code": "7340.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ard\\u00e1n Wilton", "atco_code": "8220DB007340"}}')
# 2022-07-02 14:54:02,405 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,407 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,407 INFO sqlalchemy.engine.Engine [raw sql] ('Ashmount Terminus - Curraheen Village', 'BE', '208', 'O', '{"Ashmount Terminus": {"stop_sequence": "1", "latitude": "51.90815184", "longitude": "-8.419207938", "route_data": "208", "plate_code": "246491.0", " ... (11119 characters truncated) ... 08", "plate_code": "210211.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Churraich\\u00edn", "atco_code": "8380B2102101"}}')
# 2022-07-02 14:54:02,409 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,411 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,411 INFO sqlalchemy.engine.Engine [raw sql] ('Ashmount Terminus - Marymount Hospice', 'BE', '208', 'O', '{"Ashmount Terminus": {"stop_sequence": "1", "latitude": "51.90815184", "longitude": "-8.419207938", "route_data": "208", "plate_code": "246491.0", " ... (10303 characters truncated) ... 40", "plate_code": "237221.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Osp\\u00eds Marymount", "atco_code": "8380B237221"}}')
# 2022-07-02 14:54:02,413 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,414 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,414 INFO sqlalchemy.engine.Engine [raw sql] ("Ashmount Terminus - St Patrick's Street", 'BE', '208', 'O', '{"Ashmount Terminus": {"stop_sequence": "1", "latitude": "51.90815184", "longitude": "-8.419207938", "route_data": "208", "plate_code": "246491.0", " ... (4400 characters truncated) ... e_code": "240491.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Sr\\u00e1id Naomh P\\u00e1draig", "atco_code": "8370B240491"}}')
# 2022-07-02 14:54:02,416 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,417 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,418 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Quay - Park West Hotel', 'DB', '79A', 'O', '{"Aston Quay": {"stop_sequence": "1", "latitude": "53.34655354", "longitude": "-6.260544947", "route_data": " 79, 79a", "plate_code": "326.0", "has_p ... (9146 characters truncated) ... "plate_code": "6029.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "\\u00d3st\\u00e1n Park West", "atco_code": "8220DB006029"}}')
# 2022-07-02 14:54:02,420 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,421 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,422 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Quay - Spiddal Park', 'DB', '79', 'O', '{"Aston Quay": {"stop_sequence": "1", "latitude": "53.34655354", "longitude": "-6.260544947", "route_data": " 79, 79a", "plate_code": "326.0", "has_p ... (8804 characters truncated) ... plate_code": "2908.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "P\\u00e1irc an Spid\\u00e9il", "atco_code": "8220DB002908"}}')
# 2022-07-02 14:54:02,424 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,425 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,426 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Quay - Woodford Hill', 'DB', '51D', 'O', '{"Aston Quay": {"stop_sequence": "1", "latitude": "53.34646042", "longitude": "-6.260939259", "route_data": " 25, 25a, 25b, 51d, 860", "plate_code":  ... (11755 characters truncated) ... ", "plate_code": "1966.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Cnoc \\u00c1th na Coille", "atco_code": "8230DB001966"}}')
# 2022-07-02 14:54:02,428 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,430 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,430 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Village - Deepforde Estate', 'BE', 'D5', 'I', '{"Aston Village": {"stop_sequence": "1", "latitude": "53.73288424", "longitude": "-6.32981665", "route_data": " 101x, 173, d5", "plate_code": "136021 ... (2234 characters truncated) ... ", "plate_code": "100631.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "East\\u00e1t Deepforde", "atco_code": "8310B1006301"}}')
# 2022-07-02 14:54:02,431 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,432 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,433 INFO sqlalchemy.engine.Engine [raw sql] ('Aston Village - Wilton Terrace', 'BE', '101X', 'I', '{"Aston Village": {"stop_sequence": "1", "latitude": "53.73288424", "longitude": "-6.32981665", "route_data": " 101x, 173, d5", "plate_code": "136021 ... (8427 characters truncated) ... , nx", "plate_code": "135311.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ard\\u00e1n Wilton", "atco_code": "8220B1353101"}}')
# 2022-07-02 14:54:02,435 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,436 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,437 INFO sqlalchemy.engine.Engine [raw sql] ('Athboy - Busáras', 'BE', '111', 'I', '{"Athboy": {"stop_sequence": "1", "latitude": "53.62173991", "longitude": "-6.921000697", "route_data": " 111, 111a, 111x", "plate_code": "103021.0", ... (6209 characters truncated) ... 11", "plate_code": "103131.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Eaglais Chill Dealga", "atco_code": "8310B1031301"}}')
# 2022-07-02 14:54:02,438 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,440 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,441 INFO sqlalchemy.engine.Engine [raw sql] ('Athboy - Cavan Bus Station', 'BE', '111A', 'I', '{"Athboy": {"stop_sequence": "1", "latitude": "53.62189877", "longitude": "-6.9206792", "route_data": " 111, 111a, 111x", "plate_code": "135891.0", " ... (2134 characters truncated) ...  "plate_code": "135861.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "St Bus an Chabh\\u00e1in", "atco_code": "8520B1358601"}}')
# 2022-07-02 14:54:02,442 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,443 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,444 INFO sqlalchemy.engine.Engine [raw sql] ('Athboy - UCD Belfield Campus', 'BE', '111', 'I', '{"Athboy": {"stop_sequence": "1", "latitude": "53.62173991", "longitude": "-6.921000697", "route_data": " 111, 111a, 111x", "plate_code": "103021.0", ... (6189 characters truncated) ... 115, 180", "plate_code": "135061.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "COB\\u00c1C", "atco_code": "8250B1350601"}}')
# 2022-07-02 14:54:02,446 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,447 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,447 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Abbey Road', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (2469 characters truncated) ... 90", "plate_code": "138451.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br na Mainistreach", "atco_code": "8310B138451"}}')
# 2022-07-02 14:54:02,448 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,449 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,449 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Castle Street', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1671 characters truncated) ... _code": "135761.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sr\\u00e1id an Chaisle\\u00e1in", "atco_code": "8330B1357601"}}')
# 2022-07-02 14:54:02,450 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,451 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,452 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Claremorris', 'BE', '440', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (3209 characters truncated) ... , 64", "plate_code": "151051.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Cl Chlainne Mhuiris", "atco_code": "8490B151051"}}')
# 2022-07-02 14:54:02,453 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,454 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,454 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Colbert Station', 'BE', '72', 'I', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (4171 characters truncated) ...  a2", "plate_code": "500191.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Oile\\u00e1n Golden", "atco_code": "8330B5001901"}}')
# 2022-07-02 14:54:02,456 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,457 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,457 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Longford Station', 'BE', '466', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1347 characters truncated) ...  a2", "plate_code": "500191.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Oile\\u00e1n Golden", "atco_code": "8330B5001901"}}')
# 2022-07-02 14:54:02,458 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,459 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,460 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Mart Road', 'BE', '461', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1356 characters truncated) ... te_code": "555751.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "B\\u00f3thar na Marglainne", "atco_code": "8500B5557501"}}')
# 2022-07-02 14:54:02,461 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,462 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,462 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Mill Street', 'BE', '440', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (7538 characters truncated) ... , "plate_code": "555711.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sr\\u00e1id an Mhuilinn", "atco_code": "8490B5557101"}}')
# 2022-07-02 14:54:02,464 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,465 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,465 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Monaghan Bus Stn', 'BE', '65', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (2496 characters truncated) ... te_code": "155921.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Stn Bus Mhuineach\\u00e1in", "atco_code": "8540B1559201"}}')
# 2022-07-02 14:54:02,466 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,468 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,468 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Mullingar Station', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (1884 characters truncated) ... 0", "plate_code": "555391.0", "has_pole": "Unknown", "has_shelter": "Unknown", "stop_name_ga": "ITBAL \\u00c1tha Luain", "atco_code": "8330B555391"}}')
# 2022-07-02 14:54:02,469 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,486 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,487 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - The Long Walk', 'BE', '70', 'O', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (3979 characters truncated) ... te_code": "105091.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Si\\u00fal\\u00e1n Fada", "atco_code": "8300B1050901"}}')
# 2022-07-02 14:54:02,488 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,489 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,489 INFO sqlalchemy.engine.Engine [raw sql] ('Athlone Station - Waterford Bus Stn', 'BE', '73', 'I', '{"Athlone Station": {"stop_sequence": "1", "latitude": "53.42658765", "longitude": "-7.935225814", "route_data": " 20, 440, 461, 466, 65, 70, 72, 73, ... (4935 characters truncated) ... late_code": "355051.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "St\\u00e1is Phort Lairge", "atco_code": "8440B3550501"}}')
# 2022-07-02 14:54:02,491 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,492 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,492 INFO sqlalchemy.engine.Engine [raw sql] ('Aulden Grange - Eden Quay', 'DB', '27B', 'I', '{"Aulden Grange": {"stop_sequence": "1", "latitude": "53.39740937", "longitude": "-6.232485568", "route_data": " 17a, 27b", "plate_code": "7044.0", " ... (10312 characters truncated) ...  61, 84x", "plate_code": "303.0", "has_pole": "Pole", "has_shelter": "Shelter", "stop_name_ga": "C\\u00e9 \\u00c9idin", "atco_code": "8220DB000303"}}')
# 2022-07-02 14:54:02,494 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,495 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,496 INFO sqlalchemy.engine.Engine [raw sql] ('Bailieborough - Kells', 'BE', '108', 'I', '{"Bailieborough": {"stop_sequence": "1", "latitude": "53.91622076", "longitude": "-6.969365197", "route_data": " 108, 166", "plate_code": "130911.0", ... (986 characters truncated) ... 9a, 109x, 187", "plate_code": "135391.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Ceanannas", "atco_code": "8310B1353901"}}')
# 2022-07-02 14:54:02,496 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,497 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,498 INFO sqlalchemy.engine.Engine [raw sql] ('Balbriggan Station - Millfield Centre', 'BE', 'B1', 'O', '{"Balbriggan Station": {"stop_sequence": "1", "latitude": "53.61166546", "longitude": "-6.182799777", "route_data": " b1", "plate_code": "134741.0",  ... (1883 characters truncated) ... a": " 191, b1", "plate_code": "134861.0", "has_pole": "Pole", "has_shelter": "Shelter", "stop_name_ga": "IS Millfield", "atco_code": "8240B1348601"}}')
# 2022-07-02 14:54:02,499 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,500 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,501 INFO sqlalchemy.engine.Engine [raw sql] ('Balbriggan Station - The Hastings', 'BE', 'B1', 'O', '{"Balbriggan Station": {"stop_sequence": "1", "latitude": "53.61166546", "longitude": "-6.182799777", "route_data": " b1", "plate_code": "134741.0",  ... (1339 characters truncated) ... ata": " b1", "plate_code": "134771.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "The Hastings", "atco_code": "8240B1347701"}}')
# 2022-07-02 14:54:02,501 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,503 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,503 INFO sqlalchemy.engine.Engine [raw sql] ('Baldoyle Church - Abbey St Lower', 'DB', '29A', 'I', '{"Baldoyle Church": {"stop_sequence": "1", "latitude": "53.39964609", "longitude": "-6.128037574", "route_data": " 29a", "plate_code": "950.0", "has_ ... (12328 characters truncated) ... : " 29a", "plate_code": "291.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sd na Mainistreach", "atco_code": "8220DB000291"}}')
# 2022-07-02 14:54:02,505 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,506 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,507 INFO sqlalchemy.engine.Engine [raw sql] ('Balgaddy Road - East Road', 'DB', '151', 'I', '{"Balgaddy Road": {"stop_sequence": "1", "latitude": "53.33979309", "longitude": "-6.426147786", "route_data": "151", "plate_code": "4606.0", "has_po ... (13957 characters truncated) ... e_data": " 13, 151", "plate_code": "4554.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Pfizer", "atco_code": "8230DB004554"}}')
# 2022-07-02 14:54:02,512 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,513 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,514 INFO sqlalchemy.engine.Engine [raw sql] ('Balgaddy Road - Eden Quay', 'DB', '151', 'I', '{"Balgaddy Road": {"stop_sequence": "1", "latitude": "53.33979309", "longitude": "-6.426147786", "route_data": "151", "plate_code": "4606.0", "has_po ... (11446 characters truncated) ... , 817", "plate_code": "297.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "C\\u00e9 \\u00c9idin", "atco_code": "8220DB000297"}}')
# 2022-07-02 14:54:02,515 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,517 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,517 INFO sqlalchemy.engine.Engine [raw sql] ('Balgriffin Cottages - Sutton Park School', 'ODMA', '102C', 'O', '{"Balgriffin Cottages": {"stop_sequence": "1", "latitude": "53.40810555", "longitude": "-6.17810192", "route_data": " 102c, 42, 43", "plate_code": "1 ... (11198 characters truncated) ... a, 31b", "plate_code": "685.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sc Chill Fhionntain", "atco_code": "8240DB000685"}}')
# 2022-07-02 14:54:02,519 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,520 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,520 INFO sqlalchemy.engine.Engine [raw sql] ('Ballaghaderreen - Galway Bus Station', 'BE', '429', 'I', '{"Ballaghaderreen": {"stop_sequence": "1", "latitude": "53.90180597", "longitude": "-8.578868792", "route_data": " 22, 731", "plate_code": "530161.0" ... (2726 characters truncated) ... , "plate_code": "555041.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Stn Bus na Gaillimhe", "atco_code": "8460B5550401"}}')
# 2022-07-02 14:54:02,521 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,522 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:02,522 INFO sqlalchemy.engine.Engine [raw sql] ('Ballentree Avenue - Scoil Oilibheir', 'ODMA', '236T', 'I', '{"Ballentree Avenue": {"stop_sequence": "1", "latitude": "53.41704744", "longitude": "-6.386030725", "route_data": " 236, 236a, 236t, 238, 40d, 40e", ... (6061 characters truncated) ...  39", "plate_code": "1883.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Scoil Oilibh\\u00e9ir", "atco_code": "8240DB001883"}}')
# 2022-07-02 14:54:02,523 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:02,525 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# ...
# 2022-07-02 14:54:05,900 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Clane Garda Station', 'DCOM', '120', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30529725", "longitude": "-6.216680531", "route_data": " 120, 120a, 125, 39a, 46a, 904", "plate_code":  ... (260 characters truncated) ... 120f, 120x", "plate_code": "104781.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "SG Chlaonadh", "atco_code": "8260B1047801"}}')
# 2022-07-02 14:54:05,902 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,903 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,904 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Dodsboro Road', 'DB', '25X', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30496107", "longitude": "-6.21703967", "route_data": " 25x, 41x", "plate_code": "4953.0", "has_pole":  ... (14488 characters truncated) ...  25x", "plate_code": "3890.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br Bhaile an Dodaigh", "atco_code": "8230DB003890"}}')
# 2022-07-02 14:54:05,906 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,910 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,911 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Donaghmede Rdbt', 'DB', '27X', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30489662", "longitude": "-6.216937317", "route_data": " 27x, 32x, 66x, 67x, 77x", "plate_code": "4952. ... (11940 characters truncated) ... plate_code": "4594.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Timp Dhomhnach M\\u00edde", "atco_code": "8220DB004594"}}')
# 2022-07-02 14:54:05,913 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,915 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,916 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Hansfield Road', 'DB', '39A', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30529725", "longitude": "-6.216680531", "route_data": " 120, 120a, 125, 39a, 46a, 904", "plate_code":  ... (20981 characters truncated) ... ate_code": "7162.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "B\\u00f3thar Ph\\u00e1irc Hans", "atco_code": "8240DB007162"}}')
# 2022-07-02 14:54:05,919 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,921 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,922 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Hewlett Packard', 'DB', '66X', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30489662", "longitude": "-6.216937317", "route_data": " 27x, 32x, 66x, 67x, 77x", "plate_code": "4952. ... (15470 characters truncated) ...  66b, 66x", "plate_code": "4003.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Hewlett Packard", "atco_code": "8260DB004003"}}')
# 2022-07-02 14:54:05,925 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,928 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,929 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Kingsbry', 'DB', '66X', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30489662", "longitude": "-6.216937317", "route_data": " 27x, 32x, 66x, 67x, 77x", "plate_code": "4952. ... (18241 characters truncated) ... 6, 66e, 66x, 847", "plate_code": "5114.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Kingsbry", "atco_code": "8260DB005114"}}')
# 2022-07-02 14:54:05,931 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,932 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,933 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Kingswood Avenue', 'ODMA', '175', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30525503", "longitude": "-6.216862359", "route_data": " 17, 175", "plate_code": "765.0", "has_pole": " ... (17658 characters truncated) ...  "plate_code": "6002.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ascaill Choill an R\\u00ed", "atco_code": "8230DB006002"}}')
# 2022-07-02 14:54:05,935 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,936 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,937 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Knocksedan Drive', 'DB', '41X', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30496107", "longitude": "-6.21703967", "route_data": " 25x, 41x", "plate_code": "4953.0", "has_pole":  ... (13789 characters truncated) ... x", "plate_code": "4925.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Coill Bh an Tr\\u00e9in", "atco_code": "8240DB004925"}}')
# 2022-07-02 14:54:05,939 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,940 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,940 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Millview', 'DB', '32X', 'I', '{"UCD": {"stop_sequence": "1", "latitude": "53.30489662", "longitude": "-6.216937317", "route_data": " 27x, 32x, 66x, 67x, 77x", "plate_code": "4952. ... (13617 characters truncated) ... x, 42", "plate_code": "5082.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Radharc an Mhuilinn", "atco_code": "8240DB005082"}}')
# 2022-07-02 14:54:05,942 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,943 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,943 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Old Greenfield Rd', 'DB', '67X', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30489662", "longitude": "-6.216937317", "route_data": " 27x, 32x, 66x, 67x, 77x", "plate_code": "4952. ... (20757 characters truncated) ... 7, 67x", "plate_code": "5118.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Radharc na Sceiche", "atco_code": "8260DB005118"}}')
# 2022-07-02 14:54:05,945 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,949 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,950 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - River Forest', 'DB', '66X', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30489662", "longitude": "-6.216937317", "route_data": " 27x, 32x, 66x, 67x, 77x", "plate_code": "4952. ... (14374 characters truncated) ... a, 66x", "plate_code": "3994.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Foraois na hAbhann", "atco_code": "8260DB003994"}}')
# 2022-07-02 14:54:05,954 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,955 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,955 INFO sqlalchemy.engine.Engine [raw sql] ('UCD - Toughers Ind Estate', 'DCOM', '125', 'O', '{"UCD": {"stop_sequence": "1", "latitude": "53.30529725", "longitude": "-6.216680531", "route_data": " 120, 120a, 125, 39a, 46a, 904", "plate_code":  ... (6696 characters truncated) ... _code": "103871.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "East\\u00e1t Tionscla\\u00edoch", "atco_code": "8260B1038701"}}')
# 2022-07-02 14:54:05,956 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,957 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,957 INFO sqlalchemy.engine.Engine [raw sql] ('UCD Belfield Campus - Abbey Road', 'BE', '103X', 'O', '{"UCD Belfield Campus": {"stop_sequence": "1", "latitude": "53.30531455", "longitude": "-6.216634793", "route_data": " 103x, 105x, 109, 109x, 111, 11 ... (3979 characters truncated) ... nx", "plate_code": "138461.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Br na Mainistreach", "atco_code": "8310B138461"}}')
# 2022-07-02 14:54:05,958 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,959 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,959 INFO sqlalchemy.engine.Engine [raw sql] ('UCD Belfield Campus - Duleek Church', 'BE', '103X', 'O', '{"UCD Belfield Campus": {"stop_sequence": "1", "latitude": "53.30531455", "longitude": "-6.216634793", "route_data": " 103x, 105x, 109, 109x, 111, 11 ... (3430 characters truncated) ... 05", "plate_code": "132831.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Eaglais Dhamhliag", "atco_code": "8310B1328301"}}')
# 2022-07-02 14:54:05,960 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,961 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,961 INFO sqlalchemy.engine.Engine [raw sql] ('UCD Belfield Campus - Fairyhouse Cross', 'BE', '105X', 'O', '{"UCD Belfield Campus": {"stop_sequence": "1", "latitude": "53.30531455", "longitude": "-6.216634793", "route_data": " 103x, 105x, 109, 109x, 111, 11 ... (5051 characters truncated) ... ", "plate_code": "101171.0", "has_pole": "Pole", "has_shelter": "Shelter", "stop_name_ga": "Crois Thigh na Si\\u00f3g", "atco_code": "8310B1011701"}}')
# 2022-07-02 14:54:05,962 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,963 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,963 INFO sqlalchemy.engine.Engine [raw sql] ('UCD Belfield Campus - Mullingar Station', 'BE', '115', 'O', '{"UCD Belfield Campus": {"stop_sequence": "1", "latitude": "53.30531455", "longitude": "-6.216634793", "route_data": " 103x, 105x, 109, 109x, 111, 11 ... (4850 characters truncated) ... , 70", "plate_code": "135781.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "An Muileann gCearr", "atco_code": "8330B1357801"}}')
# 2022-07-02 14:54:05,964 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,965 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,965 INFO sqlalchemy.engine.Engine [raw sql] ('UCD Sports Centre - Wendell Avenue', 'DB', '142', 'I', '{"UCD Sports Centre": {"stop_sequence": "1", "latitude": "53.30820211", "longitude": "-6.230065457", "route_data": " 142, 179", "plate_code": "877.0" ... (13378 characters truncated) ... , 32x, 42", "plate_code": "3616.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Ascaill Wendell", "atco_code": "8240DB003616"}}')
# 2022-07-02 14:54:05,966 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,967 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,968 INFO sqlalchemy.engine.Engine [raw sql] ('UCH Galway - Galway Bus Station', 'BE', '64', 'O', '{"UCH Galway": {"stop_sequence": "1", "latitude": "53.27639202", "longitude": "-9.063489327", "route_data": " 402, 411, 414, 424, 434, 64", "plate_co ... (313 characters truncated) ... , "plate_code": "555041.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Stn Bus na Gaillimhe", "atco_code": "8460B5550401"}}')
# 2022-07-02 14:54:05,969 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,970 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,970 INFO sqlalchemy.engine.Engine [raw sql] ('UL Student Centre - National Tech Park', 'BE', '304', 'O', '{"UL Student Centre": {"stop_sequence": "1", "latitude": "52.67278099", "longitude": "-8.570757043", "route_data": " 304, 304a, 323, 323x, 735", "pla ... (1099 characters truncated) ... te_code": "609351.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "P\\u00e1irc Teicni\\u00fail", "atco_code": "8410B609351"}}')
# 2022-07-02 14:54:05,970 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,971 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,971 INFO sqlalchemy.engine.Engine [raw sql] ('UL Student Centre - Parnell Street', 'BE', '304A', 'I', '{"UL Student Centre": {"stop_sequence": "1", "latitude": "52.67278099", "longitude": "-8.570757043", "route_data": " 304, 304a, 323, 323x, 735", "pla ... (4329 characters truncated) ... 9", "plate_code": "603011.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sr\\u00e1id Parnell", "atco_code": "8400B603011"}}')
# 2022-07-02 14:54:05,972 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,973 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,973 INFO sqlalchemy.engine.Engine [raw sql] ('UL Student Centre - Sarsfield Street', 'BE', '304', 'O', '{"UL Student Centre": {"stop_sequence": "1", "latitude": "52.67278099", "longitude": "-8.570757043", "route_data": " 304, 304a, 323, 323x, 735", "pla ... (5813 characters truncated) ... _code": "607831.0", "has_pole": "Pole", "has_shelter": "No Shelter", "stop_name_ga": "Sd an tS\\u00e1irs\\u00e9alaigh", "atco_code": "8400B6078301"}}')
# 2022-07-02 14:54:05,974 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,975 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,975 INFO sqlalchemy.engine.Engine [raw sql] ("UL Student Centre - St Nessan's Church", 'BE', '304', 'O', '{"UL Student Centre": {"stop_sequence": "1", "latitude": "52.67278099", "longitude": "-8.570757043", "route_data": " 304, 304a, 323, 323x, 735", "pla ... (14392 characters truncated) ...  "plate_code": "607811.0", "has_pole": "No Pole", "has_shelter": "Shelter", "stop_name_ga": "Acl Br Abhainn Mh\\u00f3r", "atco_code": "8410B607811"}}')
# 2022-07-02 14:54:05,976 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-02 14:54:05,977 INFO sqlalchemy.engine.Engine INSERT INTO static_stops (route_description, operator, route_name, direction, stops) VALUES (%s, %s, %s, %s, %s)
# 2022-07-02 14:54:05,977 INFO sqlalchemy.engine.Engine [raw sql] ('Ulsterbus Depot - Ballintra', 'BE', '480', 'I', '{"Ulsterbus Depot": {"stop_sequence": "1", "latitude": "54.99662876", "longitude": "-7.317866335", "route_data": " 480, 64, 956", "plate_code": "1581 ... (2082 characters truncated) ... "480", "plate_code": "631151.0", "has_pole": "No Pole", "has_shelter": "No Shelter", "stop_name_ga": "Baile an tSratha", "atco_code": "8530B631151"}}')
# 2022-07-02 14:54:05,978 INFO sqlalchemy.engine.Engine COMMIT
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
