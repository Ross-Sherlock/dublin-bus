# %% [markdown]
# # data clean

# %%
for i in range(1, 13):
    print('!ipython Leavetimes_DataCleaning_Month.ipynb', i)
# Out:
# !ipython Leavetimes_DataCleaning_Month.ipynb 1
# !ipython Leavetimes_DataCleaning_Month.ipynb 2
# !ipython Leavetimes_DataCleaning_Month.ipynb 3
# !ipython Leavetimes_DataCleaning_Month.ipynb 4
# !ipython Leavetimes_DataCleaning_Month.ipynb 5
# !ipython Leavetimes_DataCleaning_Month.ipynb 6
# !ipython Leavetimes_DataCleaning_Month.ipynb 7
# !ipython Leavetimes_DataCleaning_Month.ipynb 8
# !ipython Leavetimes_DataCleaning_Month.ipynb 9
# !ipython Leavetimes_DataCleaning_Month.ipynb 10
# !ipython Leavetimes_DataCleaning_Month.ipynb 11
# !ipython Leavetimes_DataCleaning_Month.ipynb 12

# %%
# !ipython Leavetimes_DataCleaning_Month.ipynb 1
# !ipython Leavetimes_DataCleaning_Month.ipynb 2
# !ipython Leavetimes_DataCleaning_Month.ipynb 3
# !ipython Leavetimes_DataCleaning_Month.ipynb 4
# !ipython Leavetimes_DataCleaning_Month.ipynb 5
# !ipython Leavetimes_DataCleaning_Month.ipynb 6
# !ipython Leavetimes_DataCleaning_Month.ipynb 7
# !ipython Leavetimes_DataCleaning_Month.ipynb 8
# !ipython Leavetimes_DataCleaning_Month.ipynb 9
# !ipython Leavetimes_DataCleaning_Month.ipynb 10
# !ipython Leavetimes_DataCleaning_Month.ipynb 11
# !ipython Leavetimes_DataCleaning_Month.ipynb 12
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9638178 entries, 0 to 9638177
# Data columns (total 18 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   DATASOURCE       object
#  1   DAYOFSERVICE     object
#  2   TRIPID           int64
#  3   PROGRNUMBER      int64
#  4   STOPPOINTID      int64
#  5   PLANNEDTIME_ARR  int64
#  6   PLANNEDTIME_DEP  int64
#  7   ACTUALTIME_ARR   int64
#  8   ACTUALTIME_DEP   int64
#  9   VEHICLEID        int64
#  10  PASSENGERS       float64
#  11  PASSENGERSIN     float64
#  12  PASSENGERSOUT    float64
#  13  DISTANCE         float64
#  14  SUPPRESSED       float64
#  15  JUSTIFICATIONID  float64
#  16  LASTUPDATE       object
#  17  NOTE             float64
# dtypes: float64(7), int64(8), object(3)
# memory usage: 1.3+ GB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9517775 entries, 0 to 9638175
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
# ...

# %% [markdown]
# # pre modeling

# %%
for i in range(1, 13):
    print('!ipython Leavetimes_PreModeling_Month.ipynb', i)
# Out:
# !ipython Leavetimes_PreModeling_Month.ipynb 1
# !ipython Leavetimes_PreModeling_Month.ipynb 2
# !ipython Leavetimes_PreModeling_Month.ipynb 3
# !ipython Leavetimes_PreModeling_Month.ipynb 4
# !ipython Leavetimes_PreModeling_Month.ipynb 5
# !ipython Leavetimes_PreModeling_Month.ipynb 6
# !ipython Leavetimes_PreModeling_Month.ipynb 7
# !ipython Leavetimes_PreModeling_Month.ipynb 8
# !ipython Leavetimes_PreModeling_Month.ipynb 9
# !ipython Leavetimes_PreModeling_Month.ipynb 10
# !ipython Leavetimes_PreModeling_Month.ipynb 11
# !ipython Leavetimes_PreModeling_Month.ipynb 12

# %%
# !ipython Leavetimes_PreModeling_Month.ipynb 1
# !ipython Leavetimes_PreModeling_Month.ipynb 2
# !ipython Leavetimes_PreModeling_Month.ipynb 3
# !ipython Leavetimes_PreModeling_Month.ipynb 4
# !ipython Leavetimes_PreModeling_Month.ipynb 5
# !ipython Leavetimes_PreModeling_Month.ipynb 6
# !ipython Leavetimes_PreModeling_Month.ipynb 7
# !ipython Leavetimes_PreModeling_Month.ipynb 8
# !ipython Leavetimes_PreModeling_Month.ipynb 9
# !ipython Leavetimes_PreModeling_Month.ipynb 10
# !ipython Leavetimes_PreModeling_Month.ipynb 11
# !ipython Leavetimes_PreModeling_Month.ipynb 12
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9323130 entries, 0 to 9323129
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   DAYOFSERVICE    object
#  1   TRIPID          int64
#  2   PROGRNUMBER     int64
#  3   STOPPOINTID     int64
#  4   ACTUALTIME_ARR  object
#  5   ACTUALTIME_DEP  object
#  6   PLANNEDTIME     object
#  7   SKIP            float64
#  8   LINEID          object
#  9   ROUTEID         object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 711.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9049608 entries, 0 to 9049607
# Data columns (total 11 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   DAYOFSERVICE         datetime64[ns]
#  1   TRIPID               object
#  2   STARTSTOP            object
#  3   LINEID               object
#  4   MONTH                object
#  5   DAY                  object
#  6   HOUR                 int64
# ...

# %% [markdown]
# # combine and separted by lineid

# %%
# !ipython Combine_Premodeling_and_Separate_by_LineID.ipynb
# Out:
# Now concat month1
# month1 have 9049608 rows
# Now concat month2
# month2 have 8003315 rows
# Now concat month3
# month3 have 7678954 rows
# Now concat month4
# month4 have 8431443 rows
# Now concat month5
# month5 have 8813183 rows
# Now concat month6
# month6 have 8374976 rows
# Now concat month7
# month7 have 8638830 rows
# Now concat month8
# month8 have 8585436 rows
# Now concat month9
# month9 have 8194853 rows
# Now concat month10
# month10 have 8443207 rows
# Now concat month11
# month11 have 8220643 rows
# Now concat month12
# month12 have 6987331 rows

# %% [markdown]
# # run model template

# %%
import pandas as pd

# %%
df = pd.read_csv('../Final_DB/trips_journey_time_cleaned.csv')
df.head()
# Out:
#   DAYOFSERVICE   TRIPID LINEID  ROUTEID
# 0   2018-02-07  6253783   68_1    68_80
# 1   2018-02-07  6254942  45A_2   45A_70
# 2   2018-02-07  6259460  25A_1  25A_273
# 3   2018-02-07  6253175   14_1    14_15
# 4   2018-02-07  6248240  77A_2   77A_28

# %%
lineids = list(df['LINEID'].unique())

# %%
len(lineids)
# Out:
# 252

# %%
i = 0
for lineid in lineids:
    print('!ipython Model_Run.ipynb', lineid)
    i+=1
    if not(i % 40):
        print(i, '---------------------------------------------', i)
# Out:
# !ipython Model_Run.ipynb 68_1
# !ipython Model_Run.ipynb 45A_2
# !ipython Model_Run.ipynb 25A_1
# !ipython Model_Run.ipynb 14_1
# !ipython Model_Run.ipynb 77A_2
# !ipython Model_Run.ipynb 39_2
# !ipython Model_Run.ipynb 16_1
# !ipython Model_Run.ipynb 40D_1
# !ipython Model_Run.ipynb 27B_2
# !ipython Model_Run.ipynb 142_2
# !ipython Model_Run.ipynb 83_2
# !ipython Model_Run.ipynb 130_1
# !ipython Model_Run.ipynb 15_1
# !ipython Model_Run.ipynb 46A_1
# !ipython Model_Run.ipynb 33_1
# !ipython Model_Run.ipynb 7_2
# !ipython Model_Run.ipynb 39A_1
# !ipython Model_Run.ipynb 39A_2
# !ipython Model_Run.ipynb 1_2
# !ipython Model_Run.ipynb 41_2
# !ipython Model_Run.ipynb 67X_1
# !ipython Model_Run.ipynb 59_1
# !ipython Model_Run.ipynb 9_1
# !ipython Model_Run.ipynb 40_1
# !ipython Model_Run.ipynb 239_2
# !ipython Model_Run.ipynb 130_2
# !ipython Model_Run.ipynb 84_1
# !ipython Model_Run.ipynb 53_1
# !ipython Model_Run.ipynb 185_1
# !ipython Model_Run.ipynb 41_1
# ...

# %%
# !ipython Model_Run.ipynb 68_1
# !ipython Model_Run.ipynb 45A_2
# !ipython Model_Run.ipynb 25A_1
# !ipython Model_Run.ipynb 14_1
# !ipython Model_Run.ipynb 77A_2
# !ipython Model_Run.ipynb 39_2
# !ipython Model_Run.ipynb 16_1
# !ipython Model_Run.ipynb 40D_1
# !ipython Model_Run.ipynb 27B_2
# !ipython Model_Run.ipynb 142_2
# !ipython Model_Run.ipynb 83_2
# !ipython Model_Run.ipynb 130_1
# !ipython Model_Run.ipynb 15_1
# !ipython Model_Run.ipynb 46A_1
# !ipython Model_Run.ipynb 33_1
# !ipython Model_Run.ipynb 7_2
# !ipython Model_Run.ipynb 39A_1
# !ipython Model_Run.ipynb 39A_2
# !ipython Model_Run.ipynb 1_2
# !ipython Model_Run.ipynb 41_2
# !ipython Model_Run.ipynb 67X_1
# !ipython Model_Run.ipynb 59_1
# !ipython Model_Run.ipynb 9_1
# !ipython Model_Run.ipynb 40_1
# !ipython Model_Run.ipynb 239_2
# !ipython Model_Run.ipynb 130_2
# !ipython Model_Run.ipynb 84_1
# !ipython Model_Run.ipynb 53_1
# !ipython Model_Run.ipynb 185_1
# !ipython Model_Run.ipynb 41_1
# !ipython Model_Run.ipynb 40D_2
# !ipython Model_Run.ipynb 151_1
# !ipython Model_Run.ipynb 13_2
# !ipython Model_Run.ipynb 15B_1
# !ipython Model_Run.ipynb 65B_2
# !ipython Model_Run.ipynb 29A_2
# !ipython Model_Run.ipynb 33_2
# !ipython Model_Run.ipynb 61_1
# !ipython Model_Run.ipynb 140_1
# !ipython Model_Run.ipynb 123_1
# Out:
# 1957_1958
# 2133_6244
# 1956_1957
# 6011_2133
# 3383_3384
# 1955_1956
# 1959_1960
# 1954_1955
# 1960_4379
# 1958_1959
# 1950_1951
# 1951_1952
# 1952_1953
# 1970_1971
# 1949_1950
# 1953_1954
# 2115_6011
# 1948_1949
# 1969_1970
# 1968_1969
# 4379_1968
# 1971_2114
# 2167_3383
# 1370_1371
# 2114_2115
# 1947_1948
# 1946_1947
# 2134_3378
# 1371_1372
# 1369_1370
# 6244_2134
# 1367_1369
# 1286_1288
# 1288_1289
# 1289_1360
# 1372_1373
# 1373_1374
# 1374_1946
# 3398_3399
# 1364_1365
# 2166_2167
# 1363_1364
# 3378_3379
# 1366_1367
# 3379_4669
# 1362_1363
# 1360_1362
# 1285_1286
# 1365_1366
# 1284_1285
# 4456_1284
# 2165_2166
# 1278_1282
# 1282_4456
# 4669_2165
# 3397_3398
# 3393_3394
# 3394_3396
# 3396_3397
# 3392_3393
# 3390_6119
# 6119_3392
# 3389_3390
# 4559_3389
# 3387_4559
# 3386_3387
# 3385_3386
# 6188_6215
# 6215_6184
# 6187_6188
# 3399_6187
# 3384_3385
# 3384_7483
# 7483_3385
# 4495_7546
# 7547_1278
# 1957_1958
# 2133_6244
# 1956_1957
# 6011_2133
# 3383_3384
# 1955_1956
# 1959_1960
# ...

# %%
# !ipython Model_Run.ipynb 14_2
# !ipython Model_Run.ipynb 7_1
# !ipython Model_Run.ipynb 79A_1
# !ipython Model_Run.ipynb 38A_2
# !ipython Model_Run.ipynb 46A_2
# !ipython Model_Run.ipynb 31_2
# !ipython Model_Run.ipynb 15B_2
# !ipython Model_Run.ipynb 69_2
# !ipython Model_Run.ipynb 44_2
# !ipython Model_Run.ipynb 42_1
# !ipython Model_Run.ipynb 67_2
# !ipython Model_Run.ipynb 184_1
# !ipython Model_Run.ipynb 238_2
# !ipython Model_Run.ipynb 145_1
# !ipython Model_Run.ipynb 17A_1
# !ipython Model_Run.ipynb 83_1
# !ipython Model_Run.ipynb 32_1
# !ipython Model_Run.ipynb 27A_1
# !ipython Model_Run.ipynb 17_2
# !ipython Model_Run.ipynb 27X_1
# !ipython Model_Run.ipynb 122_2
# !ipython Model_Run.ipynb 25A_2
# !ipython Model_Run.ipynb 54A_2
# !ipython Model_Run.ipynb 66_1
# !ipython Model_Run.ipynb 150_1
# !ipython Model_Run.ipynb 56A_1
# !ipython Model_Run.ipynb 37_2
# !ipython Model_Run.ipynb 27_2
# !ipython Model_Run.ipynb 27A_2
# !ipython Model_Run.ipynb 42_2
# !ipython Model_Run.ipynb 15A_2
# !ipython Model_Run.ipynb 65_2
# !ipython Model_Run.ipynb 123_2
# !ipython Model_Run.ipynb 145_2
# !ipython Model_Run.ipynb 9_2
# !ipython Model_Run.ipynb 150_2
# !ipython Model_Run.ipynb 47_1
# !ipython Model_Run.ipynb 76_2
# !ipython Model_Run.ipynb 79_2
# !ipython Model_Run.ipynb 79A_2
# Out:
# 519_521
# 4384_519
# 7659_523
# 522_7659
# 521_522
# 516_4384
# 523_669
# 515_516
# 242_243
# 672_4382
# 670_671
# 669_670
# 217_242
# 216_217
# 671_672
# 1187_1188
# 497_515
# 1188_216
# 1186_1187
# 4382_1185
# 1185_1186
# 244_245
# 246_248
# 245_246
# 297_496
# 7490_497
# 496_7490
# 1037_1038
# 1038_2998
# 1070_1071
# 1071_4528
# 1170_1069
# 1069_1070
# 1167_1168
# 1168_1169
# 1169_1170
# 3000_3001
# 3001_3002
# 4709_1037
# 1166_1167
# 1036_4709
# 3002_1166
# 4528_1072
# 2999_3000
# 2998_2999
# 4708_4336
# 1054_1036
# 1053_1054
# 2852_4707
# 4707_4708
# 2851_2852
# 1052_1053
# 2850_2851
# 2847_4397
# 2849_2850
# 4397_2848
# 2846_2847
# 2848_2849
# 2845_2846
# 1051_1052
# 4336_1051
# 6041_2826
# 2844_2845
# 1072_7577
# 2826_2842
# 1354_7589
# 7578_7582
# 7589_7578
# 2843_2844
# 7577_1353
# 2842_2843
# 1353_1354
# 243_244
# 7582_297
# 243_254
# 254_244
# 519_521
# 4384_519
# 7659_523
# 522_7659
# 521_522
# 516_4384
# 523_669
# 515_516
# 242_243
# 672_4382
# 670_671
# 669_670
# ...

# %%
# !ipython Model_Run.ipynb 83A_1
# !ipython Model_Run.ipynb 63_1
# !ipython Model_Run.ipynb 33B_1
# !ipython Model_Run.ipynb 27B_1
# !ipython Model_Run.ipynb 4_1
# !ipython Model_Run.ipynb 120_2
# !ipython Model_Run.ipynb 41C_1
# !ipython Model_Run.ipynb 16_2
# !ipython Model_Run.ipynb 70_2
# !ipython Model_Run.ipynb 84A_2
# !ipython Model_Run.ipynb 220_2
# !ipython Model_Run.ipynb 151_2
# !ipython Model_Run.ipynb 32X_1
# !ipython Model_Run.ipynb 17_1
# !ipython Model_Run.ipynb 68A_1
# !ipython Model_Run.ipynb 1_1
# !ipython Model_Run.ipynb 84X_1
# !ipython Model_Run.ipynb 41C_2
# !ipython Model_Run.ipynb 38_2
# !ipython Model_Run.ipynb 102_2
# !ipython Model_Run.ipynb 83A_2
# !ipython Model_Run.ipynb 37_1
# !ipython Model_Run.ipynb 270_1
# !ipython Model_Run.ipynb 77A_1
# !ipython Model_Run.ipynb 51X_2
# !ipython Model_Run.ipynb 65B_1
# !ipython Model_Run.ipynb 76_1
# !ipython Model_Run.ipynb 33X_2
# !ipython Model_Run.ipynb 75_2
# !ipython Model_Run.ipynb 220_1
# !ipython Model_Run.ipynb 26_2
# !ipython Model_Run.ipynb 270_2
# !ipython Model_Run.ipynb 66A_1
# !ipython Model_Run.ipynb 29A_1
# !ipython Model_Run.ipynb 69_1
# !ipython Model_Run.ipynb 31A_1
# !ipython Model_Run.ipynb 49_2
# !ipython Model_Run.ipynb 111_2
# !ipython Model_Run.ipynb 185_2
# !ipython Model_Run.ipynb 122_1
# Out:
# 2486_2487
# 2481_2482
# 1077_2479
# 1076_1077
# 1020_1076
# 1019_1020
# 1018_1019
# 2479_2480
# 2480_2481
# 2482_2483
# 2485_2486
# 2484_2485
# 2483_2484
# 1017_1018
# 2448_5026
# 2489_2448
# 2488_2489
# 1016_1017
# 2487_2488
# 2491_2492
# 2490_2491
# 188_189
# 187_188
# 185_186
# 189_190
# 186_187
# 181_182
# 184_185
# 1566_1567
# 336_1279
# 2450_2490
# 7423_1566
# 7424_7423
# 183_184
# 182_183
# 4456_1284
# 1285_1016
# 1283_4456
# 1279_1283
# 7425_7424
# 5026_2450
# 1284_1285
# 4891_7458
# 7458_7425
# 190_1614
# 1614_1615
# 6273_4891
# 4788_6273
# 6228_4788
# 1615_1478
# 6230_6228
# 315_336
# 1479_315
# 176_181
# 1478_1479
# 175_176
# 1567_173
# 174_175
# 173_174
# 7350_6230
# 1181_7350
# 1556_1557
# 1555_1556
# 1557_1181
# 7132_6230
# 324_7500
# 2486_2487
# 2481_2482
# 1077_2479
# 1076_1077
# 1020_1076
# 1019_1020
# 1018_1019
# 2479_2480
# 2480_2481
# 2482_2483
# 2485_2486
# 2484_2485
# 2483_2484
# 1017_1018
# 2448_5026
# 2489_2448
# 2488_2489
# 1016_1017
# 2487_2488
# 2491_2492
# ...

# %%
# !ipython Model_Run.ipynb 18_1
# !ipython Model_Run.ipynb 15_2
# !ipython Model_Run.ipynb 120_1
# !ipython Model_Run.ipynb 11_1
# !ipython Model_Run.ipynb 14C_2
# !ipython Model_Run.ipynb 67_1
# !ipython Model_Run.ipynb 70_1
# !ipython Model_Run.ipynb 65_1
# !ipython Model_Run.ipynb 33X_1
# !ipython Model_Run.ipynb 13_1
# !ipython Model_Run.ipynb 40_2
# !ipython Model_Run.ipynb 39_1
# !ipython Model_Run.ipynb 114_1
# !ipython Model_Run.ipynb 26_1
# !ipython Model_Run.ipynb 4_2
# !ipython Model_Run.ipynb 68_2
# !ipython Model_Run.ipynb 75_1
# !ipython Model_Run.ipynb 76A_1
# !ipython Model_Run.ipynb 44B_2
# !ipython Model_Run.ipynb 79_1
# !ipython Model_Run.ipynb 31A_2
# !ipython Model_Run.ipynb 32_2
# !ipython Model_Run.ipynb 140_2
# !ipython Model_Run.ipynb 102_1
# !ipython Model_Run.ipynb 38A_1
# !ipython Model_Run.ipynb 7A_2
# !ipython Model_Run.ipynb 43_1
# !ipython Model_Run.ipynb 25_2
# !ipython Model_Run.ipynb 17A_2
# !ipython Model_Run.ipynb 18_2
# !ipython Model_Run.ipynb 66_2
# !ipython Model_Run.ipynb 104_2
# !ipython Model_Run.ipynb 15A_1
# !ipython Model_Run.ipynb 11_2
# !ipython Model_Run.ipynb 84_2
# !ipython Model_Run.ipynb 33A_2
# !ipython Model_Run.ipynb 16C_2
# !ipython Model_Run.ipynb 238_1
# !ipython Model_Run.ipynb 239_1
# !ipython Model_Run.ipynb 42D_1
# Out:
# 2788_2789
# 4527_2788
# 2790_903
# 2789_2790
# 903_904
# 904_779
# 2477_2478
# 2474_2475
# 2475_2476
# 2476_2477
# 2478_4527
# 2473_2474
# 2472_2473
# 2471_2472
# 415_416
# 2497_2471
# 2800_2801
# 2801_7599
# 7599_375
# 416_417
# 417_2800
# 414_415
# 2465_2466
# 2496_2497
# 2318_2319
# 2797_414
# 2182_2778
# 2702_2784
# 2785_2786
# 2784_2785
# 2796_2797
# 781_2796
# 2466_2467
# 2181_2182
# 2786_2787
# 2701_2702
# 2319_2464
# 2495_2496
# 2700_2701
# 2464_2465
# 2467_2494
# 2494_2495
# 2787_2181
# 2696_2697
# 2697_2700
# 2185_1421
# 2689_2696
# 2778_2185
# 2317_2318
# 1421_2317
# 2688_2689
# 2205_2687
# 2687_2688
# 4799_2205
# 2204_4888
# 4888_4799
# 780_781
# 779_780
# 2203_2204
# 2202_2203
# 4361_2202
# 4359_4360
# 4360_4361
# 2788_2789
# 4527_2788
# 2790_903
# 2789_2790
# 903_904
# 904_779
# 2477_2478
# 2474_2475
# 2475_2476
# 2476_2477
# 2478_4527
# 2473_2474
# 2472_2473
# 2471_2472
# 415_416
# 2497_2471
# 2800_2801
# 2801_7599
# 7599_375
# 416_417
# 417_2800
# 414_415
# 2465_2466
# ...

# %%
# !ipython Model_Run.ipynb 7A_1
# !ipython Model_Run.ipynb 38_1
# !ipython Model_Run.ipynb 66A_2
# !ipython Model_Run.ipynb 25_1
# !ipython Model_Run.ipynb 31B_2
# !ipython Model_Run.ipynb 66X_2
# !ipython Model_Run.ipynb 31D_2
# !ipython Model_Run.ipynb 33D_1
# !ipython Model_Run.ipynb 27_1
# !ipython Model_Run.ipynb 43_2
# !ipython Model_Run.ipynb 39X_2
# !ipython Model_Run.ipynb 104_1
# !ipython Model_Run.ipynb 44_1
# !ipython Model_Run.ipynb 184_2
# !ipython Model_Run.ipynb 56A_2
# !ipython Model_Run.ipynb 31_1
# !ipython Model_Run.ipynb 41B_2
# !ipython Model_Run.ipynb 61_2
# !ipython Model_Run.ipynb 25B_1
# !ipython Model_Run.ipynb 53_2
# !ipython Model_Run.ipynb 84X_2
# !ipython Model_Run.ipynb 67X_2
# !ipython Model_Run.ipynb 63_2
# !ipython Model_Run.ipynb 49_1
# !ipython Model_Run.ipynb 7D_2
# !ipython Model_Run.ipynb 46E_2
# !ipython Model_Run.ipynb 33B_2
# !ipython Model_Run.ipynb 25B_2
# !ipython Model_Run.ipynb 45A_1
# !ipython Model_Run.ipynb 47_2
# !ipython Model_Run.ipynb 142_1
# !ipython Model_Run.ipynb 32X_2
# !ipython Model_Run.ipynb 66X_1
# !ipython Model_Run.ipynb 118_2
# !ipython Model_Run.ipynb 51D_1
# !ipython Model_Run.ipynb 15D_1
# !ipython Model_Run.ipynb 41A_2
# !ipython Model_Run.ipynb 25D_1
# !ipython Model_Run.ipynb 38D_2
# !ipython Model_Run.ipynb 114_2
# Out:
# 3221_4982
# 3220_3221
# 3219_3220
# 429_3032
# 3203_3204
# 2036_2040
# 2035_2036
# 428_429
# 427_428
# 3202_3203
# 3047_3202
# 3217_3218
# 3033_3034
# 3032_3033
# 2040_3047
# 426_427
# 425_426
# 3218_3219
# 3216_3217
# 3040_3041
# 3215_3216
# 3039_3040
# 3036_3037
# 3037_3038
# 3038_3039
# 3208_3209
# 3034_3036
# 3207_3208
# 3209_3210
# 424_425
# 3206_3207
# 3214_3215
# 3212_3213
# 3213_3214
# 421_422
# 3211_3212
# 3210_4981
# 420_421
# 423_424
# 4981_3211
# 422_423
# 419_420
# 418_419
# 417_418
# 416_417
# 415_416
# 414_415
# 3204_3205
# 413_414
# 412_413
# 411_412
# 3205_3206
# 410_411
# 409_410
# 4725_273
# 408_409
# 273_405
# 405_408
# 3041_2035
# 4962_4725
# 1174_4725
# 3041_3042
# 3042_2035
# 3221_4982
# 3220_3221
# 3219_3220
# 429_3032
# 3203_3204
# 2036_2040
# 2035_2036
# 428_429
# 427_428
# 3202_3203
# 3047_3202
# 3217_3218
# 3033_3034
# 3032_3033
# 2040_3047
# 426_427
# 425_426
# 3218_3219
# 3216_3217
# 3040_3041
# 3215_3216
# 3039_3040
# 3036_3037
# 3037_3038
# 3038_3039
# ...

# %%
# !ipython Model_Run.ipynb 84A_1
# !ipython Model_Run.ipynb 59_2
# !ipython Model_Run.ipynb 54A_1
# !ipython Model_Run.ipynb 40B_1
# !ipython Model_Run.ipynb 66B_2
# !ipython Model_Run.ipynb 111_1
# !ipython Model_Run.ipynb 16C_1
# !ipython Model_Run.ipynb 66B_1
# !ipython Model_Run.ipynb 40B_2
# !ipython Model_Run.ipynb 38B_2
# !ipython Model_Run.ipynb 236_2
# !ipython Model_Run.ipynb 39X_1
# !ipython Model_Run.ipynb 41B_1
# !ipython Model_Run.ipynb 7B_2
# !ipython Model_Run.ipynb 76A_2
# !ipython Model_Run.ipynb 51D_2
# !ipython Model_Run.ipynb 31B_1
# !ipython Model_Run.ipynb 41X_2
# !ipython Model_Run.ipynb 33A_1
# !ipython Model_Run.ipynb 44B_1
# !ipython Model_Run.ipynb 31D_1
# !ipython Model_Run.ipynb 41X_1
# !ipython Model_Run.ipynb 25D_2
# !ipython Model_Run.ipynb 27X_2
# !ipython Model_Run.ipynb 38D_1
# !ipython Model_Run.ipynb 14C_1
# !ipython Model_Run.ipynb 7B_1
# !ipython Model_Run.ipynb 33D_2
# !ipython Model_Run.ipynb 68A_2
# !ipython Model_Run.ipynb 236_1
# !ipython Model_Run.ipynb 38B_1
# !ipython Model_Run.ipynb 40E_2
# !ipython Model_Run.ipynb 161_2
# !ipython Model_Run.ipynb 70D_1
# !ipython Model_Run.ipynb 69X_2
# !ipython Model_Run.ipynb 116_1
# !ipython Model_Run.ipynb 77X_2
# !ipython Model_Run.ipynb 25X_1
# !ipython Model_Run.ipynb 25X_2
# !ipython Model_Run.ipynb 42D_2
# !ipython Model_Run.ipynb 7D_1
# !ipython Model_Run.ipynb 40E_1
# !ipython Model_Run.ipynb 68X_2
# !ipython Model_Run.ipynb 69X_1
# !ipython Model_Run.ipynb 15D_2
# !ipython Model_Run.ipynb 70D_2
# !ipython Model_Run.ipynb 116_2
# !ipython Model_Run.ipynb 161_1
# !ipython Model_Run.ipynb 16D_1
# !ipython Model_Run.ipynb 33E_1
# !ipython Model_Run.ipynb 41D_1
# !ipython Model_Run.ipynb 41D_2
# Out:
# 3131_3132
# 3120_3122
# 3132_3133
# 3130_3131
# 3127_3128
# 3126_3127
# 3124_3125
# 3123_3124
# 3122_3123
# 3125_3126
# 3118_3119
# 3119_3120
# 3117_3118
# 3128_7638
# 7638_3130
# 3116_3117
# 4156_4168
# 7294_4156
# 4131_7294
# 3115_3116
# 4130_4131
# 4128_4129
# 4127_4128
# 3139_4124
# 4126_4127
# 4124_4125
# 3138_3139
# 4125_4126
# 4129_4130
# 3133_5046
# 3135_3136
# 3136_3138
# 3134_3135
# 5046_7639
# 3114_3115
# 7188_3082
# 3082_3114
# 7639_3134
# 7639_7640
# 7640_3134
# 429_3032
# 427_429
# 426_427
# 425_426
# 423_424
# 424_425
# 422_423
# 3032_3114
# 3131_3132
# 3120_3122
# 3132_3133
# 3130_3131
# 3127_3128
# 3126_3127
# 3124_3125
# 3123_3124
# 3122_3123
# 3125_3126
# 3118_3119
# 3119_3120
# 3117_3118
# 3128_7638
# 7638_3130
# 3116_3117
# 4156_4168
# 7294_4156
# 4131_7294
# 3115_3116
# 4130_4131
# 4128_4129
# 4127_4128
# 3139_4124
# 4126_4127
# 4124_4125
# 3138_3139
# 4125_4126
# 4129_4130
# 3133_5046
# 3135_3136
# 3136_3138
# 3134_3135
# 5046_7639
# 3114_3115
# 7188_3082
# ...
